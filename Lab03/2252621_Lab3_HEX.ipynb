# %% [markdown]
# **Home Exercise:**
#
# a) Improve the model by using interpolation smoothing with the "Stupid Backoff" method (Brants et al., 2007).
#
# b) Compare with the results from In Class Exercise.
#
# c) Use the newly built model to generate the next words for a given word sequence.
#
# d) Combine with a function that calculates the distance between words to predict the correct word for a misspelled word position. (from difflib import get_close_matches)

# %% [markdown]
# # Import

# %%
# %pip install gdown matplotlib nltk
# Out:
# Requirement already satisfied: gdown in c:\python312\lib\site-packages (5.2.0)
# Requirement already satisfied: matplotlib in c:\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: nltk in c:\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\python312\lib\site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in c:\python312\lib\site-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in c:\python312\lib\site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in c:\python312\lib\site-packages (from gdown) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python312\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python312\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python312\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: click in c:\python312\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\python312\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\python312\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\python312\lib\site-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python312\lib\site-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python312\lib\site-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\python312\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import sys
# import os
# import platform

# # Python environment details
# print("Python executable being used:", sys.executable)
# print("Python version:", sys.version)

# # Operating System details
# print("Operating System:", platform.system())
# print("OS Version:", platform.version())
# print("OS Release:", platform.release())

# # Machine and architecture details
# print("Machine:", platform.machine())

# # Visual Studio Code details (based on environment variable)
# vscode_info = os.environ.get('VSCODE_PID', None)
# if vscode_info:
#     print("Running in Visual Studio Code")
# else:
#     print("Not running in Visual Studio Code")
# Out:
# Python executable being used: c:\Python312\python.exe
# Python version: 3.12.6 (tags/v3.12.6:a4a2d2b, Sep  6 2024, 20:11:23) [MSC v.1940 64 bit (AMD64)]
# Operating System: Windows
# OS Version: 10.0.19045
# OS Release: 10
# Machine: AMD64
# Running in Visual Studio Code

# %%
import os
from collections import defaultdict
import math
import gdown
import re
import matplotlib.pyplot as plt
from difflib import get_close_matches
import nltk
nltk.download('punkt')  # Download the Punkt tokenizer model
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Function Definitions

# %% [markdown]
# ## Load data

# %%
def clean_sentence(sentence):
    """
    Clean a sentence by removing unwanted characters like '-', '(', ')', etc.
    """
    cleaned = re.sub(r'[\(\)-]', '', sentence)  # Remove specific characters
    cleaned = re.sub(r'[^\w\s.,!?]', '', cleaned)  # Keep only alphanumeric, spaces, and basic punctuation
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()  # Remove extra spaces and trim
    
    return cleaned

# %%
def load_data(filepath):
    """
    Load and preprocess text data from a file.
    Split the data into sentences using nltk's sentence tokenizer.
    """
    with open(filepath, "r", encoding="utf-8") as file:
        text = file.read()
    
    # Tokenize the text into sentences
    sentences = sent_tokenize(text)
    
    # Clean each sentence
    cleaned_sentences = [clean_sentence(sentence) for sentence in sentences]

    # Debug: Print the first 10 sentences
    # print("First 10 sentences from the file:")
    # for i, sentence in enumerate(cleaned_sentences[:10], start=1):
    #     print(f"{i}: {sentence}")
    
    return cleaned_sentences  # Return the list of tokenized sentences

# %% [markdown]
# ## Build n-gram model

# %%
def build_ngram_model(corpus, n):
    """
    Build an n-gram model from a given corpus and given n.
    """
    ngram_counts = defaultdict(int)
    n_minus_1_counts = defaultdict(int)
    vocabulary = set()

    for sentence in corpus:
        # Tokenize and add padding based on n
        tokens = sentence.split()  # Tokenize the sentence
        if n > 1:
            tokens = (["<s>"] * (n - 1)) + tokens + (["</s>"] * (n - 1))
        
        # Update vocabulary
        vocabulary.update(tokens)

        # Generate n-grams and (n-1)-grams
        for i in range(len(tokens) - n + 1):
            ngram = tuple(tokens[i:i + n])
            n_minus_1_gram = tuple(tokens[i:i + n - 1])
            ngram_counts[ngram] += 1
            n_minus_1_counts[n_minus_1_gram] += 1

    return ngram_counts, n_minus_1_counts, len(vocabulary)

# %% [markdown]
# ## Compute Sentence Probabilities with laplace smoothed probabilities

# %%
def compute_laplace_probability(ngram, ngram_counts, n_minus_1_counts, vocab_size):
    """
    Compute the Laplace smoothed probability of an n-gram.
    """
    ngram_count = ngram_counts[ngram]
    n_minus_1_count = n_minus_1_counts[ngram[:-1]] if len(ngram) > 1 else sum(ngram_counts.values())
    return (ngram_count + 1) / (n_minus_1_count + vocab_size)

# %%
def sentence_probability(sentence, ngram_counts, n_minus_1_counts, vocab_size, n):
    """
    Compute the probability of a sentence using an n-gram model with Laplace smoothing.
    Debug statements added to trace computation.
    """
    # Add padding based on n-gram size
    if n > 1:
        tokens = ["<s>"] * (n - 1) + sentence.split() + ["</s>"] * (n - 1)
    else:
        tokens = sentence.split()

    print(f"Tokens with padding for n={n}: {tokens}")  

    prob = 1.0  # Initialize probability
    for i in range(len(tokens) - n + 1):
        ngram = tuple(tokens[i:i + n])
        ngram_prob = compute_laplace_probability(ngram, ngram_counts, n_minus_1_counts, vocab_size)
        print(f"N-gram: {ngram}, Probability: {ngram_prob}")  

        prob *= ngram_prob

    print(f"Final sentence probability: {prob}")  
    return prob

# %%
def compute_perplexity(sentence, ngram_counts, n_minus_1_counts, vocab_size, n):
    """
    Compute the perplexity of a sentence using an n-gram model.
    """
    # Add padding based on n-gram size
    if n > 1:
        tokens = ["<s>"] * (n - 1) + sentence.split() + ["</s>"] * (n - 1)
    else:
        tokens = sentence.split()
        
    prob = 0.0
    for i in range(len(tokens) - n + 1):
        ngram = tuple(tokens[i:i + n])
        prob += math.log(compute_laplace_probability(ngram, ngram_counts, n_minus_1_counts, vocab_size))
    prob = -prob / len(tokens)
    return math.exp(prob)

# %% [markdown]
# ## Compute Sentence Probabilities with Stupid Backoff method

# %%
def compute_stupid_backoff_probability(ngram, ngram_models, alpha=0.4):
    """
    Compute the Stupid Backoff score for a given n-gram using proper backoff logic.
    
    Args:
        ngram (tuple): The n-gram to compute the score for.
        ngram_models (dict): A dictionary where keys are n (order of n-grams) and values are tuples of 
                             (ngram_counts, n_minus_1_counts, vocab_size).
        alpha (float): The backoff factor (default is 0.4).

    Returns:
        float: The Stupid Backoff score of the n-gram.
    """
    # print(f"Computing Stupid Backoff for n-gram: {ngram}")  # Debug: Initial n-gram
    
    # Get the highest available n-gram model
    ngram_model = ngram_models.get(len(ngram))
    
    if ngram_model:
        ngram_counts, n_minus_1_counts, _ = ngram_model
        
        # Check if the highest-order n-gram exists
        if ngram in ngram_counts and ngram_counts[ngram] > 0:
            ngram_count = ngram_counts[ngram]
            n_minus_1_count = n_minus_1_counts.get(ngram[:-1], 0) if len(ngram) > 1 else sum(ngram_counts.values())

            if n_minus_1_count > 0:
                prob = ngram_count / n_minus_1_count
                # print(f"Probability for n-gram {ngram}: {prob}")
                return prob

    # Backoff: If the n-gram was not found, reduce the order and apply backoff
    if len(ngram) > 1:
        # print(f"Backing off from n-gram: {ngram}")
        backoff_prob = alpha * compute_stupid_backoff_probability(ngram[1:], ngram_models, alpha)
        # print(f"Backoff probability for n-gram {ngram}: {backoff_prob}")
        return backoff_prob

    # Base case: Compute unigram score
    unigram_model = ngram_models.get(1)
    if unigram_model:
        unigram_counts, _, total_count = unigram_model
        unigram_count = unigram_counts.get((ngram[-1],), 0)
        
        if unigram_count > 0:
            # Compute and return the unigram probability
            if total_count > 0:
                prob = unigram_count / total_count
                # print(f"Unigram probability for {ngram[-1]}: {prob}")
                return prob
            
        if ngram == ('</s>',):
            # print("Unigram probability for </s>: 1.0")
            return 1.0
    
    # Fallback: Return alpha if all else fails
    # print(f"No match for n-gram {ngram}, returning alpha = {alpha}")
    return alpha

# %%
def sentence_probability_with_backoff(sentence, ngram_models, alpha=0.4):
    """
    Compute the probability of a sentence using Stupid Backoff smoothing with detailed debugging.
    """
    max_n = max(ngram_models.keys())
    
    tokens = ["<s>"] * (max_n - 1) + sentence.split() + ["</s>"] * (max_n - 1)
    print(f"Tokens with padding for max_n={max_n}: {tokens}")  

    # Initialize the probability
    prob = 1.0  

    # Iterate through the tokens to compute probabilities for each n-gram
    for i in range(len(tokens) - max_n + 1):
        # Extract the n-gram of maximum size
        ngram = tuple(tokens[i:i + max_n])
        ngram_prob = compute_stupid_backoff_probability(ngram, ngram_models, alpha)
        prob *= ngram_prob

    print(f"Final sentence probability with backoff: {prob}")  
    return prob

# %%
def compute_perplexity_with_backoff(sentence, ngram_models, alpha=0.4):
    """
    Compute the perplexity of a sentence using Stupid Backoff smoothing.
    """
    max_n = max(ngram_models.keys()) 
    tokens = ["<s>"] * (max_n - 1) + sentence.split() + ["</s>"] * (max_n - 1)

    log_prob = 0.0  

    # Iterate through tokens to compute log probabilities
    for i in range(len(tokens) - max_n + 1):
        ngram = tuple(tokens[i:i + max_n])
        ngram_prob = compute_stupid_backoff_probability(ngram, ngram_models, alpha)

        if ngram_prob > 0:
            log_prob += math.log(ngram_prob)
        else:
            log_prob += math.log(alpha)  

    N = len(tokens) - (max_n - 1)  
    log_prob = -log_prob / N  
    perplexity = math.exp(log_prob)  

    print(f"Final Perplexity with Backoff: {perplexity}")  
    return perplexity

# %% [markdown]
# ## Compare sentences by using soothing with laplace and with stupid backoff

# %%
def compare_sentences_with_smoothing(sentence1, sentence2, ngram_models, alpha=0.4):
    """
    Compare probabilities and perplexities of two sentences using both Laplace and Stupid Backoff.
    Determines which sentence is more likely based on both smoothing methods.
    """
    results = {"Laplace": {}, "Stupid Backoff": {}}

    # Compare using Laplace smoothing
    for n in range(1, len(ngram_models) + 1):
        ngram_counts, n_minus_1_counts, vocab_size = ngram_models[n]
        
        print("-----------------------------------")
        print("DEBUG: Comparing sentences using Laplace smoothing for", n, "-gram model")

        sentence1_prob_laplace = sentence_probability(sentence1, ngram_counts, n_minus_1_counts, vocab_size, n)
        sentence2_prob_laplace = sentence_probability(sentence2, ngram_counts, n_minus_1_counts, vocab_size, n)        

        sentence1_perplexity_laplace = compute_perplexity(sentence1, ngram_counts, n_minus_1_counts, vocab_size, n)
        sentence2_perplexity_laplace = compute_perplexity(sentence2, ngram_counts, n_minus_1_counts, vocab_size, n)

        # Determine which sentence has higher probability
        if sentence1_perplexity_laplace < sentence2_perplexity_laplace:
            higher_sentence = "Sentence 1 (Correct)"
        elif sentence2_perplexity_laplace < sentence1_perplexity_laplace:
            higher_sentence = "Sentence 2 (Incorrect)"
        else:
            higher_sentence = "Both sentences have equal probability"

        # Store Laplace comparison results
        results["Laplace"][f"{n}-gram"] = {
            "sentence1": {
                "probability": sentence1_prob_laplace,
                "perplexity": sentence1_perplexity_laplace,
            },
            "sentence2": {
                "probability": sentence2_prob_laplace,
                "perplexity": sentence2_perplexity_laplace,
            },
            "higher_probability": higher_sentence,
            "probability_difference": abs(sentence1_prob_laplace - sentence2_prob_laplace),
            "perplexity_difference": abs(sentence1_perplexity_laplace - sentence2_perplexity_laplace),
        }
        
    print("-----------------------------------")
    print("DEBUG: Comparing sentences using Stupid Backoff smoothing for", n, "-gram model")
    
    # Compare using Stupid Backoff smoothing
    sentence1_prob_backoff = sentence_probability_with_backoff(sentence1, ngram_models, alpha)
    sentence1_perplexity_backoff = compute_perplexity_with_backoff(sentence1, ngram_models, alpha)
    
    print("\n")
    
    sentence2_prob_backoff = sentence_probability_with_backoff(sentence2, ngram_models, alpha)
    sentence2_perplexity_backoff = compute_perplexity_with_backoff(sentence2, ngram_models, alpha)

    # Determine which sentence has higher probability under Backoff
    if sentence1_perplexity_backoff < sentence2_perplexity_backoff:
        higher_sentence_backoff = "Sentence 1 (Correct)"
    elif sentence2_perplexity_backoff < sentence1_perplexity_backoff:
        higher_sentence_backoff = "Sentence 2 (Incorrect)"
    else:
        higher_sentence_backoff = "Both sentences have equal probability"

    # Store Backoff comparison results
    results["Stupid Backoff"] = {
        "sentence1": {
            "probability": sentence1_prob_backoff,
            "perplexity": sentence1_perplexity_backoff,
        },
        "sentence2": {
            "probability": sentence2_prob_backoff,
            "perplexity": sentence2_perplexity_backoff,
        },
        "higher_probability": higher_sentence_backoff,
        "probability_difference": abs(sentence1_prob_backoff - sentence2_prob_backoff),
        "perplexity_difference": abs(sentence1_perplexity_backoff - sentence2_perplexity_backoff),
    }

    return results

# %% [markdown]
# ## Function for predicting the next top-k tokens

# %% [markdown]
# The Stupid Backoff method scores n-grams using relative frequencies but does **not normalize** probabilities to sum to 1. It uses a backoff mechanism to handle cases where an n-gram does not exist in the training data.
#
# ### Backoff Strategy
# - Start with the highest-order n-gram (e.g., trigram).
# - If the n-gram is **not found**, back off to the next lower-order n-gram (e.g., bigram).
# - Continue until the unigram model is reached.
# - If no match is found, return the **backoff factor** ($\alpha$).
#
# ### Backoff Factor ($\alpha$)
# - $\alpha$ is a constant multiplier used for scoring lower-order n-grams.
# - It is typically set to $0.4$, as per the original implementation of Stupid Backoff.
#
# ---
#
# ## 2. Combined Stupid Backoff with Optional Laplace Smoothing
#
# The code combines **Stupid Backoff** with an option for **Laplace Smoothing** to handle zero probabilities.
#
# ### Steps:
# 1. **Start with the Highest n-gram**:
#    - Look for the n-gram in the training data.
#    - If found:
#      - Use Laplace Smoothing:
#        $
#        P(w_i|w_{i-(n-1)}, ..., w_{i-1}) = \frac{\text{Count}(w_i, w_{i-(n-1)}, ..., w_{i-1}) + 1}{\text{Count}(w_{i-(n-1)}, ..., w_{i-1}) + V}
#        $
#        Where $V$ is the vocabulary size.
#      - Otherwise, return the relative frequency:
#        $
#        P(w_i|w_{i-(n-1)}, ..., w_{i-1}) = \frac{\text{Count}(w_i, w_{i-(n-1)}, ..., w_{i-1})}{\text{Count}(w_{i-(n-1)}, ..., w_{i-1})}
#        $
#
# 2. **Backoff to Lower-Order n-grams**:
#    - If the n-gram is not found, reduce the order (e.g., backoff from trigram to bigram).
#    - Repeat the probability calculation for the lower-order n-gram.
#
# 3. **Fallback to Unigram**:
#    - If no n-grams match, compute the unigram probability:
#      - With Laplace Smoothing:
#        $
#        P(w_i) = \frac{\text{Count}(w_i) + 1}{\text{Total Words} + V}
#        $
#      - Without Laplace Smoothing:
#        $
#        P(w_i) = \frac{\text{Count}(w_i)}{\text{Total Words}}
#        $
#
# 4. **Return Backoff Factor**:
#    - If the word is entirely unseen, return $\alpha$

# %%
def predict_next_word(sequence, ngram_models, alpha=0.4, top_k=5):
    """
    Predict the next word for a given sequence using both Laplace smoothing and Stupid Backoff.
    Uses `compute_laplace_probability()` for Laplace smoothing.
    
    Returns:
        dict: Top-k predicted words and their scores.
    """
    sequence_tokens = sequence.split()
    candidates_laplace = defaultdict(float)
    candidates_backoff = defaultdict(float)

    print(f"\nInput sequence: '{sequence}'")
    print(f"Tokens: {sequence_tokens}")

    # Iterate over n-grams (bigram and trigram models)
    for n in range(len(ngram_models), 1, -1):  # Only checking for n=3 and n=2
        ngram_model = ngram_models.get(n)
        if not ngram_model:
            continue  # Skip if this n-gram model doesn't exist

        ngram_counts, n_minus_1_counts, vocab_size = ngram_model
        if len(sequence_tokens) < (n - 1):
            continue  # Not enough context for this n-gram

        prefix = tuple(sequence_tokens[-(n - 1):])  # Extract prefix

        print(f"\nSearching for {n}-grams with prefix: {prefix}")

        # Filter n-grams matching the prefix
        matching_ngrams = {ngram: count for ngram, count in ngram_counts.items() if ngram[:-1] == prefix}

        if not matching_ngrams:
            print(f"No {n}-grams found for prefix {prefix}, backing off...")
            continue  # Move to the next lower n-gram

        for ngram, count in matching_ngrams.items():
            word = ngram[-1]  # Get the predicted word

            # Use `compute_laplace_probability()` instead of manual Laplace smoothing
            laplace_prob = compute_laplace_probability(ngram, ngram_counts, n_minus_1_counts, vocab_size)
            candidates_laplace[word] += laplace_prob

            # Stupid Backoff Probability
            backoff_prob = compute_stupid_backoff_probability(ngram, ngram_models, alpha)
            candidates_backoff[word] += backoff_prob

            print(f"Match found: {ngram}, Count: {count}, Laplace Score: {laplace_prob:.6f}, Backoff Score: {backoff_prob:.6f}")

    # Sort candidates by their scores
    sorted_candidates_laplace = sorted(candidates_laplace.items(), key=lambda x: x[1], reverse=True)
    sorted_candidates_backoff = sorted(candidates_backoff.items(), key=lambda x: x[1], reverse=True)

    print("\nTop candidate words (Laplace Smoothing):")
    for word, score in sorted_candidates_laplace[:top_k]:
        print(f"Word: {word}, Score: {score:.6f}")

    print("\nTop candidate words (Stupid Backoff):")
    for word, score in sorted_candidates_backoff[:top_k]:
        print(f"Word: {word}, Score: {score:.6f}")

    return {
        "Laplace": sorted_candidates_laplace[:top_k],
        "Stupid Backoff": sorted_candidates_backoff[:top_k]
    }

# %% [markdown]
# ## Function for correcting the misspelled word

# %%
def correct_misspelled_word(word, vocabulary, ngram_models, context, alpha=0.4, top_k=5):
    """
    Predict the correct word for a misspelled word using both Laplace and Stupid Backoff.
    Returns:
        dict: Corrected words and scores from both smoothing methods.
    """
    # Step 1: Use difflib to get similar words
    similar_words = get_close_matches(word, vocabulary, n=top_k)

    if not similar_words:
        # No similar words found; return the original word
        return {"Laplace": word, "Stupid Backoff": word}

    # Step 2: Rank similar words using both smoothing methods
    word_scores_laplace = []
    word_scores_backoff = []

    for candidate in similar_words:
        # Add the candidate to the context for scoring
        sequence_tokens = context.split() + [candidate]
        sequence = " ".join(sequence_tokens)

        # Compute Laplace probability
        laplace_prob = sentence_probability(sequence, *ngram_models[max(ngram_models.keys())], max(ngram_models.keys()))

        # Compute Stupid Backoff probability
        backoff_prob = sentence_probability_with_backoff(sequence, ngram_models, alpha)

        word_scores_laplace.append((candidate, laplace_prob))
        word_scores_backoff.append((candidate, backoff_prob))

    # Sort candidates by probability
    word_scores_laplace.sort(key=lambda x: x[1], reverse=True)
    word_scores_backoff.sort(key=lambda x: x[1], reverse=True)

    # Display top-k ranked results
    print(f"\nTop-{len(word_scores_laplace)} Predictions for '{word}' (Laplace):")
    for rank, (candidate, prob) in enumerate(word_scores_laplace, start=1):
        print(f"  {rank}. {candidate} - Probability: {prob:.10e}")

    print(f"\nTop-{len(word_scores_backoff)} Predictions for '{word}' (Stupid Backoff):")
    for rank, (candidate, prob) in enumerate(word_scores_backoff, start=1):
        print(f"  {rank}. {candidate} - Probability: {prob:.10e}")

    return {
        "Laplace": word_scores_laplace[0][0] if word_scores_laplace else word,
        "Stupid Backoff": word_scores_backoff[0][0] if word_scores_backoff else word
    }

# %% [markdown]
# ## Function for building first n-gram models

# %%
def build_ngram_models(filepath, n):
    """
    Build n-gram models 

    Args:
        filepath (str): Path to the dataset.

    Returns:
        dict: Dictionary of n-gram models (ngram_counts, n_minus_1_counts, vocab_size) 
    """
    corpus = load_data(filepath)
    ngram_models = {}
    
    for n in range(1, n + 1):  # 1-gram, 2-gram, 3-gram, 4-gram, 5-gram, ... n-gram
        ngram_counts, n_minus_1_counts, vocab_size = build_ngram_model(corpus, n)
        ngram_models[n] = (ngram_counts, n_minus_1_counts, vocab_size)
    
    return ngram_models

# %% [markdown]
# # Main Function for doing the exercises

# %% [markdown]
# ## Download tedtalk.txt

# %%
# Download tedtalk
url = "https://drive.google.com/file/d/1ZFXJVav0rZ0V2TadMuY0TxWuwxkhN-nq/view?usp=sharing"

def download_from_google_drive(url, output_filename=None):
    # Extract file ID using regex
    match = re.search(r"/d/([^/]+)", url)
    if not match:
        print("Error: Could not extract file ID from the URL.")
        return
    
    file_id = match.group(1)
    print(f"Extracted File ID: {file_id}")

    download_url = f"https://drive.google.com/uc?id={file_id}"

    if output_filename:
        gdown.download(download_url, output_filename, quiet=False)
    else:
        gdown.download(download_url, quiet=False)

url = "https://drive.google.com/file/d/1ZFXJVav0rZ0V2TadMuY0TxWuwxkhN-nq/view?usp=sharing"
download_from_google_drive(url, "tedtalk.txt")
# Out:
# Extracted File ID: 1ZFXJVav0rZ0V2TadMuY0TxWuwxkhN-nq
# Downloading...
# From: https://drive.google.com/uc?id=1ZFXJVav0rZ0V2TadMuY0TxWuwxkhN-nq
# To: e:\2_LEARNING_BKU\2_File_2\K22_HK242\CO3085_NLP\BT\Lab03\tedtalk.txt
# 100%|██████████| 40.3M/40.3M [00:07<00:00, 5.05MB/s]

# %% [markdown]
# ## Compare with the results from In Class Exercise.

# %% [markdown]
# This build_ngram_models function is just the same as in the In Class Exercise but now allow to put the params to let build n-gram models from 1-gram to n-gram
#
# In this in class exercise, the function implementation of that function is just stick the loop from 1 -> 3-gram, now just small modification frm 3-gram -> n-gram is easy

# %%
dataset_path = os.path.join(os.getcwd(), "tedtalk.txt")

print("Building n-gram models...")
ngram_models = build_ngram_models(dataset_path, 5) # build from 1-gram -> n-gram models
# Out:
# Building n-gram models...

# %%
# Example sentences for comparison
correct_sentence = "the cat sat on the mat"  
incorrect_sentence = "cat the the on mat sat"

# Compare results
comparison_results = compare_sentences_with_smoothing(correct_sentence, incorrect_sentence, ngram_models)

# Display comparison results
print("\nComparison Results:")
for method, results in comparison_results.items():
    print(f"\n{method} Smoothing:")

    if method == "Laplace":
        # Loop through each n-gram level
        for ngram, data in results.items():
            print(f"{ngram}:")
            print(f"  Correct Sentence - Probability: {data['sentence1']['probability']}, Perplexity: {data['sentence1']['perplexity']}")
            print(f"  Incorrect Sentence - Probability: {data['sentence2']['probability']}, Perplexity: {data['sentence2']['perplexity']}")
            print(f"  Higher Probability: {data['higher_probability']}")
            print(f"  Probability Difference: {data['probability_difference']}")
            print(f"  Perplexity Difference: {data['perplexity_difference']}")

    elif method == "Stupid Backoff":
        # Print results for Stupid Backoff smoothing
        print(f"  Correct Sentence - Probability: {results['sentence1']['probability']}, Perplexity: {results['sentence1']['perplexity']}")
        print(f"  Incorrect Sentence - Probability: {results['sentence2']['probability']}, Perplexity: {results['sentence2']['perplexity']}")
        print(f"  Higher Probability: {results['higher_probability']}")
        print(f"  Probability Difference: {results['probability_difference']}")
        print(f"  Perplexity Difference: {results['perplexity_difference']}")
# Out:
# -----------------------------------
# DEBUG: Comparing sentences using Laplace smoothing for 1 -gram model
# Tokens with padding for n=1: ['the', 'cat', 'sat', 'on', 'the', 'mat']
# N-gram: ('the',), Probability: 0.04309039618096174
# N-gram: ('cat',), Probability: 2.1718949687984748e-05
# N-gram: ('sat',), Probability: 6.228830853912608e-05
# N-gram: ('on',), Probability: 0.005241643121868168
# N-gram: ('the',), Probability: 0.04309039618096174
# N-gram: ('mat',), Probability: 1.0927773427916854e-06
# Final sentence probability: 1.4388166724576847e-20
# Tokens with padding for n=1: ['cat', 'the', 'the', 'on', 'mat', 'sat']
# N-gram: ('cat',), Probability: 2.1718949687984748e-05
# N-gram: ('the',), Probability: 0.04309039618096174
# N-gram: ('the',), Probability: 0.04309039618096174
# N-gram: ('on',), Probability: 0.005241643121868168
# N-gram: ('mat',), Probability: 1.0927773427916854e-06
# N-gram: ('sat',), Probability: 6.228830853912608e-05
# Final sentence probability: 1.438816672457685e-20
# -----------------------------------
# DEBUG: Comparing sentences using Laplace smoothing for 2 -gram model
# Tokens with padding for n=2: ['<s>', 'the', 'cat', 'sat', 'on', 'the', 'mat', '</s>']
# N-gram: ('<s>', 'the'), Probability: 5.430150168334655e-05
# N-gram: ('the', 'cat'), Probability: 5.848331867769217e-05
# N-gram: ('cat', 'sat'), Probability: 6.1172555544680435e-06
# N-gram: ('sat', 'on'), Probability: 0.00021371566047298328
# N-gram: ('on', 'the'), Probability: 0.056389635373798874
# N-gram: ('the', 'mat'), Probability: 4.17737990554944e-06
# N-gram: ('mat', '</s>'), Probability: 6.122911321875326e-06
# Final sentence probability: 5.988224163869548e-30
# Tokens with padding for n=2: ['<s>', 'cat', 'the', 'the', 'on', 'mat', 'sat', '</s>']
# N-gram: ('<s>', 'cat'), Probability: 3.291000102021003e-06
# N-gram: ('cat', 'the'), Probability: 6.1172555544680435e-06
# N-gram: ('the', 'the'), Probability: 5.012855886659328e-05
# N-gram: ('the', 'on'), Probability: 2.08868995277472e-06
# N-gram: ('on', 'mat'), Probability: 4.958202354154478e-06
# N-gram: ('mat', 'sat'), Probability: 6.122911321875326e-06
# N-gram: ('sat', '</s>'), Probability: 6.106161727799523e-06
# Final sentence probability: 3.907457260193631e-37
# -----------------------------------
# DEBUG: Comparing sentences using Laplace smoothing for 3 -gram model
# Tokens with padding for n=3: ['<s>', '<s>', 'the', 'cat', 'sat', 'on', 'the', 'mat', '</s>', '</s>']
# N-gram: ('<s>', '<s>', 'the'), Probability: 5.430150168334655e-05
# N-gram: ('<s>', 'the', 'cat'), Probability: 6.121974214244609e-06
# N-gram: ('the', 'cat', 'sat'), Probability: 6.122161612822255e-06
# N-gram: ('cat', 'sat', 'on'), Probability: 6.123173763425059e-06
# N-gram: ('sat', 'on', 'the'), Probability: 9.182848887038715e-05
# N-gram: ('on', 'the', 'mat'), Probability: 5.724557205500154e-06
# N-gram: ('the', 'mat', '</s>'), Probability: 6.123136270397698e-06
# N-gram: ('mat', '</s>', '</s>'), Probability: 6.123173763425059e-06
# Final sentence probability: 2.4561481326231865e-40
# Tokens with padding for n=3: ['<s>', '<s>', 'cat', 'the', 'the', 'on', 'mat', 'sat', '</s>', '</s>']
# N-gram: ('<s>', '<s>', 'cat'), Probability: 3.291000102021003e-06
# N-gram: ('<s>', 'cat', 'the'), Probability: 6.123136270397698e-06
# N-gram: ('cat', 'the', 'the'), Probability: 6.123173763425059e-06
# N-gram: ('the', 'the', 'on'), Probability: 6.122311539945021e-06
# N-gram: ('the', 'on', 'mat'), Probability: 6.123173763425059e-06
# N-gram: ('on', 'mat', 'sat'), Probability: 6.123173763425059e-06
# N-gram: ('mat', 'sat', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('sat', '</s>', '</s>'), Probability: 6.123173763425059e-06
# Final sentence probability: 1.0619404555746645e-42
# -----------------------------------
# DEBUG: Comparing sentences using Laplace smoothing for 4 -gram model
# Tokens with padding for n=4: ['<s>', '<s>', '<s>', 'the', 'cat', 'sat', 'on', 'the', 'mat', '</s>', '</s>', '</s>']
# N-gram: ('<s>', '<s>', '<s>', 'the'), Probability: 5.430150168334655e-05
# N-gram: ('<s>', '<s>', 'the', 'cat'), Probability: 6.121974214244609e-06
# N-gram: ('<s>', 'the', 'cat', 'sat'), Probability: 6.123173763425059e-06
# N-gram: ('the', 'cat', 'sat', 'on'), Probability: 6.123173763425059e-06
# N-gram: ('cat', 'sat', 'on', 'the'), Probability: 6.123173763425059e-06
# N-gram: ('sat', 'on', 'the', 'mat'), Probability: 6.122648902821316e-06
# N-gram: ('on', 'the', 'mat', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('the', 'mat', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('mat', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# Final sentence probability: 1.0727590723803431e-46
# Tokens with padding for n=4: ['<s>', '<s>', '<s>', 'cat', 'the', 'the', 'on', 'mat', 'sat', '</s>', '</s>', '</s>']
# N-gram: ('<s>', '<s>', '<s>', 'cat'), Probability: 3.291000102021003e-06
# N-gram: ('<s>', '<s>', 'cat', 'the'), Probability: 6.123136270397698e-06
# N-gram: ('<s>', 'cat', 'the', 'the'), Probability: 6.123173763425059e-06
# N-gram: ('cat', 'the', 'the', 'on'), Probability: 6.123173763425059e-06
# N-gram: ('the', 'the', 'on', 'mat'), Probability: 6.123173763425059e-06
# N-gram: ('the', 'on', 'mat', 'sat'), Probability: 6.123173763425059e-06
# N-gram: ('on', 'mat', 'sat', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('mat', 'sat', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('sat', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# Final sentence probability: 6.503361694840555e-48
# -----------------------------------
# DEBUG: Comparing sentences using Laplace smoothing for 5 -gram model
# Tokens with padding for n=5: ['<s>', '<s>', '<s>', '<s>', 'the', 'cat', 'sat', 'on', 'the', 'mat', '</s>', '</s>', '</s>', '</s>']
# N-gram: ('<s>', '<s>', '<s>', '<s>', 'the'), Probability: 5.430150168334655e-05
# N-gram: ('<s>', '<s>', '<s>', 'the', 'cat'), Probability: 6.121974214244609e-06
# N-gram: ('<s>', '<s>', 'the', 'cat', 'sat'), Probability: 6.123173763425059e-06
# N-gram: ('<s>', 'the', 'cat', 'sat', 'on'), Probability: 6.123173763425059e-06
# N-gram: ('the', 'cat', 'sat', 'on', 'the'), Probability: 6.123173763425059e-06
# N-gram: ('cat', 'sat', 'on', 'the', 'mat'), Probability: 6.123173763425059e-06
# N-gram: ('sat', 'on', 'the', 'mat', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('on', 'the', 'mat', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('the', 'mat', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('mat', '</s>', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# Final sentence probability: 6.569253303716975e-52
# Tokens with padding for n=5: ['<s>', '<s>', '<s>', '<s>', 'cat', 'the', 'the', 'on', 'mat', 'sat', '</s>', '</s>', '</s>', '</s>']
# N-gram: ('<s>', '<s>', '<s>', '<s>', 'cat'), Probability: 3.291000102021003e-06
# N-gram: ('<s>', '<s>', '<s>', 'cat', 'the'), Probability: 6.123136270397698e-06
# N-gram: ('<s>', '<s>', 'cat', 'the', 'the'), Probability: 6.123173763425059e-06
# N-gram: ('<s>', 'cat', 'the', 'the', 'on'), Probability: 6.123173763425059e-06
# N-gram: ('cat', 'the', 'the', 'on', 'mat'), Probability: 6.123173763425059e-06
# N-gram: ('the', 'the', 'on', 'mat', 'sat'), Probability: 6.123173763425059e-06
# N-gram: ('the', 'on', 'mat', 'sat', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('on', 'mat', 'sat', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('mat', 'sat', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('sat', '</s>', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# Final sentence probability: 3.9821213703911213e-53
# -----------------------------------
# DEBUG: Comparing sentences using Stupid Backoff smoothing for 5 -gram model
# Tokens with padding for max_n=5: ['<s>', '<s>', '<s>', '<s>', 'the', 'cat', 'sat', 'on', 'the', 'mat', '</s>', '</s>', '</s>', '</s>']
# Final sentence probability with backoff: 1.7623344600135057e-32
# Final Perplexity with Backoff: 1497.583914466561
#
#
# Tokens with padding for max_n=5: ['<s>', '<s>', '<s>', '<s>', 'cat', 'the', 'the', 'on', 'mat', 'sat', '</s>', '</s>', '</s>', '</s>']
# Final sentence probability with backoff: 2.8453251472498854e-38
# Final Perplexity with Backoff: 5683.119783271947
#
# Comparison Results:
#
# Laplace Smoothing:
# 1-gram:
#   Correct Sentence - Probability: 1.4388166724576847e-20, Perplexity: 2027.6784695597985
#   Incorrect Sentence - Probability: 1.438816672457685e-20, Perplexity: 2027.6784695597985
#   Higher Probability: Both sentences have equal probability
#   Probability Difference: 3.009265538105056e-36
#   Perplexity Difference: 0.0
# 2-gram:
#   Correct Sentence - Probability: 5.988224163869548e-30, Perplexity: 4496.118446353802
#   Incorrect Sentence - Probability: 3.907457260193631e-37, Perplexity: 35564.214458181865
#   Higher Probability: Sentence 1 (Correct)
#   Probability Difference: 5.988223773123822e-30
#   Perplexity Difference: 31068.096011828064
# 3-gram:
#   Correct Sentence - Probability: 2.4561481326231865e-40, Perplexity: 9140.59663500876
#   Incorrect Sentence - Probability: 1.0619404555746645e-42, Perplexity: 15753.96888598543
#   Higher Probability: Sentence 1 (Correct)
#   Probability Difference: 2.44552872806744e-40
#   Perplexity Difference: 6613.37225097667
# 4-gram:
#   Correct Sentence - Probability: 1.0727590723803431e-46, Perplexity: 6773.162319807479
#   Incorrect Sentence - Probability: 6.503361694840555e-48, Perplexity: 8555.364308721524
#   Higher Probability: Sentence 1 (Correct)
#   Probability Difference: 1.0077254554319376e-46
#   Perplexity Difference: 1782.2019889140447
# 5-gram:
#   Correct Sentence - Probability: 6.569253303716975e-52, Perplexity: 4527.846692178305
#   Incorrect Sentence - Probability: 3.9821213703911213e-53, Perplexity: 5531.577033430497
#   Higher Probability: Sentence 1 (Correct)
#   Probability Difference: 6.171041166677863e-52
#   Perplexity Difference: 1003.7303412521924
#
# Stupid Backoff Smoothing:
#   Correct Sentence - Probability: 1.7623344600135057e-32, Perplexity: 1497.583914466561
#   Incorrect Sentence - Probability: 2.8453251472498854e-38, Perplexity: 5683.119783271947
#   Higher Probability: Sentence 1 (Correct)
#   Probability Difference: 1.7623316146883583e-32
#   Perplexity Difference: 4185.535868805386

# %% [markdown]
# So based on the output, the Laplace method and Stupid Backoff method both have the ability to recognize which sentence is "correct" (We just calculate the sentences probabilities and both model generate the probability for the correct-order sentence higher than the incorrect-order sentence)

# %% [markdown]
# ## Use the newly built model to generate the next words for a given word sequence.

# %%
ngram_counts1, n_minus_1_counts1, vocab_size1 = ngram_models[1]
ngram_counts2, n_minus_1_counts2, vocab_size2 = ngram_models[2]
ngram_counts3, n_minus_1_counts3, vocab_size3 = ngram_models[3]

# %% [markdown]
# Here below, the first one is the `laplace` and the second one is `stupid backoff` prob of `P(the cat sleep | the cat)`
#
# The `laplace` is much smaller than the `stupid backoff` because it requires smoothing, and with `smoothing` it must divide with the `vocab_size` and the `vocab_size` is so big so it makes `laplace` much smaller
#
# And for predicting the next words, we just take the word that together with the current sequence get the highest prob

# %%
print((ngram_counts3[('the', 'cat', 'sleep')] + 1) / (ngram_counts2[('the', 'cat')] + vocab_size3))
print((ngram_counts3[('the', 'cat', 'sleep')]) / (ngram_counts2[('the', 'cat')]))
# Out:
# 1.224432322564451e-05
# 0.037037037037037035

# %% [markdown]
# Here I let the model predict the next word based on the current sequence of preceding words

# %%
# Predict the next word
sequence = "Today is a beautiful day. In the house the cat is"

# Predict next words using both smoothing methods
predicted_words = predict_next_word(sequence, ngram_models, alpha=0.4, top_k=5)
# Out:
# Input sequence: 'Today is a beautiful day. In the house the cat is'
# Tokens: ['Today', 'is', 'a', 'beautiful', 'day.', 'In', 'the', 'house', 'the', 'cat', 'is']
#
# Searching for 5-grams with prefix: ('house', 'the', 'cat', 'is')
# No 5-grams found for prefix ('house', 'the', 'cat', 'is'), backing off...
#
# Searching for 4-grams with prefix: ('the', 'cat', 'is')
# Match found: ('the', 'cat', 'is', 'hearing'), Count: 1, Laplace Score: 0.000012, Backoff Score: 0.166667
# Match found: ('the', 'cat', 'is', 'either'), Count: 1, Laplace Score: 0.000012, Backoff Score: 0.166667
# Match found: ('the', 'cat', 'is', 'equal'), Count: 1, Laplace Score: 0.000012, Backoff Score: 0.166667
), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'appropriate'), Count: 3, Laplace Score: 0.000016, Backoff Score: 0.000033
# Match found: ('is', 'Who'), Count: 8, Laplace Score: 0.000035, Backoff Score: 0.000087
# Match found: ('is', 'filled'), Count: 36, Laplace Score: 0.000145, Backoff Score: 0.000391
# Match found: ('is', 'deaf,'), Count: 2, Laplace Score: 0.000012, Backoff Score: 0.000022
# ...
# Match found: ('is', 'elevator'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'tribology'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'interacting'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'incorporate'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Mukuru.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'sold.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'flicking'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Jonah.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'negligible.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'shortterm'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'shore'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'rooting'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Money'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'choosing'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'taxi'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'avoidable.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Jumia.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Jomo.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'stunningly'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'isolated,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', '69.72.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'eavesdropping.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'antisocial'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'redundant,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'fictional'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'detailed'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'slowgrowing'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'fastgrowing'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'stressed'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'provocative'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'sexually'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'promiscuous,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'provocative.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'introducing'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'dramatic'), Count: 2, Laplace Score: 0.000012, Backoff Score: 0.000022
# Match found: ('is', 'tempting.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'cooked'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Snowball'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Joel,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'coparenting,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Joel.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'indispensable?'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'indispensable.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'seen.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'fatal'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'center'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'AIenabled'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Rebecca,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'theft.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'corrosive,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'predatory.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Karura'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'theft'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'selfconfident.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'positive.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Antarctica'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'appalled'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'evenly'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'diverse,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'received,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'fetching'), Count: 2, Laplace Score: 0.000012, Backoff Score: 0.000022
# Match found: ('is', 'duly'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'download'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'needing'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'attuning,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'running,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'coordinating'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'spacesuitable.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'feeling,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'afterwards.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'determined.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'upsetting'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'supportive'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'golden.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'onethirtieth'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'encompassed'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'sounded,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'instability.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'avian'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'agriculture,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'funding,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'generational.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'naked.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', '42.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'rural'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Stumai'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'unexpected,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'male.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'aggressive,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', '1985.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'super,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'paired'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'infected.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'tempting,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Japan,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'past'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'large.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'certificates'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'reinforced.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'passion?'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Musa.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'top'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Gavi?'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'coronavirus'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'enroll'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'mild,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'galvanizing'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'bestplaced'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'weeks,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'mutating,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'dampen'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'overwhelmingly'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'tasked'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Zhong'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'returning'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'SARS'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'already,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'pointofcare'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'infrastructure'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'consumer'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'walkable.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'resonant'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'milkweed.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'shared,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', '725,000,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', '725.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'makes'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'lovely,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Youre'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'unveiling?'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'disrupted.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'mean'), Count: 2, Laplace Score: 0.000012, Backoff Score: 0.000022
# Match found: ('is', 'week'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'absolutely,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'precedent'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'custommade'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'ticking,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'siniy,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'animate,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Mikmaq.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'assimilation,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'fulltime'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'US'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Eurodollar'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'productivity,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'competition,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'That'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'inventiveness,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'selfsufficiency'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'redefined,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'evil?'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'rocky,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'waterbased.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'alright.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'wound'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Mabel.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'conducting'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', '3.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'retired,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'patient,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'choreographed'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Elizabeth,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'boss.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'faltering.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'unthinkable.'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Beth,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'Nancy'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'unhappy,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
# Match found: ('is', 'dilated,'), Count: 1, Laplace Score: 0.000008, Backoff Score: 0.000011
#
# Top candidate words (Laplace Smoothing):
# Word: a, Score: 0.039304
# Word: the, Score: 0.031762
# Word: that, Score: 0.022913
# Word: not, Score: 0.013615
# Word: to, Score: 0.009494
#
# Top candidate words (Stupid Backoff):
# Word: a, Score: 0.408981
# Word: out, Score: 0.300837
# Word: either, Score: 0.233659
# Word: equal, Score: 0.233659
# Word: alive, Score: 0.233486

# %%
print(f"\nTop predictions for '{sequence}' (Laplace Smoothing):")
for rank, (word, score) in enumerate(predicted_words["Laplace"], start=1):
    print(f"{rank}. {word} - Score: {score:.6f}")

print(f"\nTop predictions for '{sequence}' (Stupid Backoff):")
for rank, (word, score) in enumerate(predicted_words["Stupid Backoff"], start=1):
    print(f"{rank}. {word} - Score: {score:.6f}")
# Out:
# Top predictions for 'Today is a beautiful day. In the house the cat is' (Laplace Smoothing):
# 1. a - Score: 0.039304
# 2. the - Score: 0.031762
# 3. that - Score: 0.022913
# 4. not - Score: 0.013615
# 5. to - Score: 0.009494
#
# Top predictions for 'Today is a beautiful day. In the house the cat is' (Stupid Backoff):
# 1. a - Score: 0.408981
# 2. out - Score: 0.300837
# 3. either - Score: 0.233659
# 4. equal - Score: 0.233659
# 5. alive - Score: 0.233486

# %% [markdown]
# ## Combine with a function that calculates the distance between words to predict the correct word for a misspelled word position. (from difflib import get_close_matches)

# %%
# Load the tokenized sentences from the dataset
tokenized_sentences = load_data("tedtalk.txt")

# Convert tokenized sentences into a vocabulary set (unique words)
vocabulary = set(word for sentence in tokenized_sentences for word in sentence.split())

print(f"Vocabulary Size: {len(vocabulary)}")  # Debug: Print vocabulary size
print(f"Sample Words: {list(vocabulary)[:20]}")  # Debug: Show some words
# Out:
# Vocabulary Size: 163312
# Sample Words: ['disembark', 'Gestapo.', 'China', 'Waters?', 'SOS', 'deformities,', 'bonanza.', 'helpless.', 'marble?', 'Lepage', 'nomads', 'Blip', 'Film', 'arrived.', 'unexploited,', 'Reykjavik', 'lubrication', 'datagrabbing', 'Jonathans', 'breathe']

# %%
# Example misspelled word correction
misspelled_word = "beautfall"
context = "Today is such a"
corrected_word = correct_misspelled_word(misspelled_word, vocabulary, ngram_models, context, alpha=0.4, top_k=5)
# Out:
# Tokens with padding for n=5: ['<s>', '<s>', '<s>', '<s>', 'Today', 'is', 'such', 'a', 'befall', '</s>', '</s>', '</s>', '</s>']
# N-gram: ('<s>', '<s>', '<s>', '<s>', 'Today'), Probability: 0.00026492550821269074
# N-gram: ('<s>', '<s>', '<s>', 'Today', 'is'), Probability: 3.0585903568763227e-05
# N-gram: ('<s>', '<s>', 'Today', 'is', 'such'), Probability: 6.123023794070464e-06
# N-gram: ('<s>', 'Today', 'is', 'such', 'a'), Probability: 6.123173763425059e-06
# N-gram: ('Today', 'is', 'such', 'a', 'befall'), Probability: 6.123173763425059e-06
# N-gram: ('is', 'such', 'a', 'befall', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('such', 'a', 'befall', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('a', 'befall', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('befall', '</s>', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# Final sentence probability: 2.6149930701220953e-45
# Tokens with padding for max_n=5: ['<s>', '<s>', '<s>', '<s>', 'Today', 'is', 'such', 'a', 'befall', '</s>', '</s>', '</s>', '</s>']
# Final sentence probability with backoff: 1.215822383625735e-25
# Tokens with padding for n=5: ['<s>', '<s>', '<s>', '<s>', 'Today', 'is', 'such', 'a', 'beautifully', '</s>', '</s>', '</s>', '</s>']
# N-gram: ('<s>', '<s>', '<s>', '<s>', 'Today'), Probability: 0.00026492550821269074
# N-gram: ('<s>', '<s>', '<s>', 'Today', 'is'), Probability: 3.0585903568763227e-05
# N-gram: ('<s>', '<s>', 'Today', 'is', 'such'), Probability: 6.123023794070464e-06
# N-gram: ('<s>', 'Today', 'is', 'such', 'a'), Probability: 6.123173763425059e-06
# N-gram: ('Today', 'is', 'such', 'a', 'beautifully'), Probability: 6.123173763425059e-06
# N-gram: ('is', 'such', 'a', 'beautifully', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('such', 'a', 'beautifully', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('a', 'beautifully', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('beautifully', '</s>', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# Final sentence probability: 2.6149930701220953e-45
# Tokens with padding for max_n=5: ['<s>', '<s>', '<s>', '<s>', 'Today', 'is', 'such', 'a', 'beautifully', '</s>', '</s>', '</s>', '</s>']
# Final sentence probability with backoff: 7.834952273933755e-23
# Tokens with padding for n=5: ['<s>', '<s>', '<s>', '<s>', 'Today', 'is', 'such', 'a', 'beautiful', '</s>', '</s>', '</s>', '</s>']
# N-gram: ('<s>', '<s>', '<s>', '<s>', 'Today'), Probability: 0.00026492550821269074
# N-gram: ('<s>', '<s>', '<s>', 'Today', 'is'), Probability: 3.0585903568763227e-05
# N-gram: ('<s>', '<s>', 'Today', 'is', 'such'), Probability: 6.123023794070464e-06
# N-gram: ('<s>', 'Today', 'is', 'such', 'a'), Probability: 6.123173763425059e-06
# N-gram: ('Today', 'is', 'such', 'a', 'beautiful'), Probability: 6.123173763425059e-06
# N-gram: ('is', 'such', 'a', 'beautiful', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('such', 'a', 'beautiful', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('a', 'beautiful', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('beautiful', '</s>', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# Final sentence probability: 2.6149930701220953e-45
# Tokens with padding for max_n=5: ['<s>', '<s>', '<s>', '<s>', 'Today', 'is', 'such', 'a', 'beautiful', '</s>', '</s>', '</s>', '</s>']
# Final sentence probability with backoff: 4.899903861285507e-20
# Tokens with padding for n=5: ['<s>', '<s>', '<s>', '<s>', 'Today', 'is', 'such', 'a', 'beautifully.', '</s>', '</s>', '</s>', '</s>']
# N-gram: ('<s>', '<s>', '<s>', '<s>', 'Today'), Probability: 0.00026492550821269074
# N-gram: ('<s>', '<s>', '<s>', 'Today', 'is'), Probability: 3.0585903568763227e-05
# N-gram: ('<s>', '<s>', 'Today', 'is', 'such'), Probability: 6.123023794070464e-06
# N-gram: ('<s>', 'Today', 'is', 'such', 'a'), Probability: 6.123173763425059e-06
# N-gram: ('Today', 'is', 'such', 'a', 'beautifully.'), Probability: 6.123173763425059e-06
# N-gram: ('is', 'such', 'a', 'beautifully.', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('such', 'a', 'beautifully.', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('a', 'beautifully.', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('beautifully.', '</s>', '</s>', '</s>', '</s>'), Probability: 0.00011020565599916733
# Final sentence probability: 4.706497608274337e-44
# Tokens with padding for max_n=5: ['<s>', '<s>', '<s>', '<s>', 'Today', 'is', 'such', 'a', 'beautifully.', '</s>', '</s>', '</s>', '</s>']
# Final sentence probability with backoff: 1.9711475869786722e-20
# Tokens with padding for n=5: ['<s>', '<s>', '<s>', '<s>', 'Today', 'is', 'such', 'a', 'beautifully,', '</s>', '</s>', '</s>', '</s>']
# N-gram: ('<s>', '<s>', '<s>', '<s>', 'Today'), Probability: 0.00026492550821269074
# N-gram: ('<s>', '<s>', '<s>', 'Today', 'is'), Probability: 3.0585903568763227e-05
# N-gram: ('<s>', '<s>', 'Today', 'is', 'such'), Probability: 6.123023794070464e-06
# N-gram: ('<s>', 'Today', 'is', 'such', 'a'), Probability: 6.123173763425059e-06
# N-gram: ('Today', 'is', 'such', 'a', 'beautifully,'), Probability: 6.123173763425059e-06
# N-gram: ('is', 'such', 'a', 'beautifully,', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('such', 'a', 'beautifully,', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('a', 'beautifully,', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('beautifully,', '</s>', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# Final sentence probability: 2.6149930701220953e-45
# Tokens with padding for max_n=5: ['<s>', '<s>', '<s>', '<s>', 'Today', 'is', 'such', 'a', 'beautifully,', '</s>', '</s>', '</s>', '</s>']
# Final sentence probability with backoff: 1.702151337076029e-24
#
# Top-5 Predictions for 'beautfall' (Laplace):
#   1. beautifully. - Probability: 4.7064976083e-44
#   2. befall - Probability: 2.6149930701e-45
#   3. beautifully - Probability: 2.6149930701e-45
#   4. beautiful - Probability: 2.6149930701e-45
#   5. beautifully, - Probability: 2.6149930701e-45
#
# Top-5 Predictions for 'beautfall' (Stupid Backoff):
#   1. beautiful - Probability: 4.8999038613e-20
#   2. beautifully. - Probability: 1.9711475870e-20
#   3. beautifully - Probability: 7.8349522739e-23
#   4. beautifully, - Probability: 1.7021513371e-24
#   5. befall - Probability: 1.2158223836e-25

# %%
print(f"Misspelled Word: {misspelled_word}")
print(f"Corrected Word: {corrected_word}")
# Out:
# Misspelled Word: beautfall
# Corrected Word: {'Laplace': 'beautifully.', 'Stupid Backoff': 'beautiful'}

# %%
misspelled_word = "healp"
context = "thank you very much for your"
corrected_word = correct_misspelled_word(misspelled_word, vocabulary, ngram_models, context, alpha=0.4, top_k=5)
# Out:
# Tokens with padding for n=5: ['<s>', '<s>', '<s>', '<s>', 'thank', 'you', 'very', 'much', 'for', 'your', 'help', '</s>', '</s>', '</s>', '</s>']
# N-gram: ('<s>', '<s>', '<s>', '<s>', 'thank'), Probability: 1.6455000510105016e-06
# N-gram: ('<s>', '<s>', '<s>', 'thank', 'you'), Probability: 6.123173763425059e-06
# N-gram: ('<s>', '<s>', 'thank', 'you', 'very'), Probability: 6.123173763425059e-06
# N-gram: ('<s>', 'thank', 'you', 'very', 'much'), Probability: 6.123173763425059e-06
# N-gram: ('thank', 'you', 'very', 'much', 'for'), Probability: 8.57155102215746e-05
# N-gram: ('you', 'very', 'much', 'for', 'your'), Probability: 8.57055402509948e-05
# N-gram: ('very', 'much', 'for', 'your', 'help'), Probability: 6.122573930080206e-06
# N-gram: ('much', 'for', 'your', 'help', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('for', 'your', 'help', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('your', 'help', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('help', '</s>', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# Final sentence probability: 2.3885610038974823e-56
# Tokens with padding for max_n=5: ['<s>', '<s>', '<s>', '<s>', 'thank', 'you', 'very', 'much', 'for', 'your', 'help', '</s>', '</s>', '</s>', '</s>']
# Final sentence probability with backoff: 1.8680265908009832e-20
# Tokens with padding for n=5: ['<s>', '<s>', '<s>', '<s>', 'thank', 'you', 'very', 'much', 'for', 'your', 'heap', '</s>', '</s>', '</s>', '</s>']
# N-gram: ('<s>', '<s>', '<s>', '<s>', 'thank'), Probability: 1.6455000510105016e-06
# N-gram: ('<s>', '<s>', '<s>', 'thank', 'you'), Probability: 6.123173763425059e-06
# N-gram: ('<s>', '<s>', 'thank', 'you', 'very'), Probability: 6.123173763425059e-06
# N-gram: ('<s>', 'thank', 'you', 'very', 'much'), Probability: 6.123173763425059e-06
# N-gram: ('thank', 'you', 'very', 'much', 'for'), Probability: 8.57155102215746e-05
# N-gram: ('you', 'very', 'much', 'for', 'your'), Probability: 8.57055402509948e-05
# N-gram: ('very', 'much', 'for', 'your', 'heap'), Probability: 6.122573930080206e-06
# N-gram: ('much', 'for', 'your', 'heap', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('for', 'your', 'heap', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('your', 'heap', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('heap', '</s>', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# Final sentence probability: 2.3885610038974823e-56
# Tokens with padding for max_n=5: ['<s>', '<s>', '<s>', '<s>', 'thank', 'you', 'very', 'much', 'for', 'your', 'heap', '</s>', '</s>', '</s>', '</s>']
# Final sentence probability with backoff: 7.395392218401979e-25
# Tokens with padding for n=5: ['<s>', '<s>', '<s>', '<s>', 'thank', 'you', 'very', 'much', 'for', 'your', 'heal', '</s>', '</s>', '</s>', '</s>']
# N-gram: ('<s>', '<s>', '<s>', '<s>', 'thank'), Probability: 1.6455000510105016e-06
# N-gram: ('<s>', '<s>', '<s>', 'thank', 'you'), Probability: 6.123173763425059e-06
# N-gram: ('<s>', '<s>', 'thank', 'you', 'very'), Probability: 6.123173763425059e-06
# N-gram: ('<s>', 'thank', 'you', 'very', 'much'), Probability: 6.123173763425059e-06
# N-gram: ('thank', 'you', 'very', 'much', 'for'), Probability: 8.57155102215746e-05
# N-gram: ('you', 'very', 'much', 'for', 'your'), Probability: 8.57055402509948e-05
# N-gram: ('very', 'much', 'for', 'your', 'heal'), Probability: 6.122573930080206e-06
# N-gram: ('much', 'for', 'your', 'heal', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('for', 'your', 'heal', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('your', 'heal', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('heal', '</s>', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# Final sentence probability: 2.3885610038974823e-56
# Tokens with padding for max_n=5: ['<s>', '<s>', '<s>', '<s>', 'thank', 'you', 'very', 'much', 'for', 'your', 'heal', '</s>', '</s>', '</s>', '</s>']
# Final sentence probability with backoff: 1.172697908918028e-23
# Tokens with padding for n=5: ['<s>', '<s>', '<s>', '<s>', 'thank', 'you', 'very', 'much', 'for', 'your', 'helps', '</s>', '</s>', '</s>', '</s>']
# N-gram: ('<s>', '<s>', '<s>', '<s>', 'thank'), Probability: 1.6455000510105016e-06
# N-gram: ('<s>', '<s>', '<s>', 'thank', 'you'), Probability: 6.123173763425059e-06
# N-gram: ('<s>', '<s>', 'thank', 'you', 'very'), Probability: 6.123173763425059e-06
# N-gram: ('<s>', 'thank', 'you', 'very', 'much'), Probability: 6.123173763425059e-06
# N-gram: ('thank', 'you', 'very', 'much', 'for'), Probability: 8.57155102215746e-05
# N-gram: ('you', 'very', 'much', 'for', 'your'), Probability: 8.57055402509948e-05
# N-gram: ('very', 'much', 'for', 'your', 'helps'), Probability: 6.122573930080206e-06
# N-gram: ('much', 'for', 'your', 'helps', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('for', 'your', 'helps', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('your', 'helps', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('helps', '</s>', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# Final sentence probability: 2.3885610038974823e-56
# Tokens with padding for max_n=5: ['<s>', '<s>', '<s>', '<s>', 'thank', 'you', 'very', 'much', 'for', 'your', 'helps', '</s>', '</s>', '</s>', '</s>']
# Final sentence probability with backoff: 4.796440095934997e-23
# Tokens with padding for n=5: ['<s>', '<s>', '<s>', '<s>', 'thank', 'you', 'very', 'much', 'for', 'your', 'help?', '</s>', '</s>', '</s>', '</s>']
# N-gram: ('<s>', '<s>', '<s>', '<s>', 'thank'), Probability: 1.6455000510105016e-06
# N-gram: ('<s>', '<s>', '<s>', 'thank', 'you'), Probability: 6.123173763425059e-06
# N-gram: ('<s>', '<s>', 'thank', 'you', 'very'), Probability: 6.123173763425059e-06
# N-gram: ('<s>', 'thank', 'you', 'very', 'much'), Probability: 6.123173763425059e-06
# N-gram: ('thank', 'you', 'very', 'much', 'for'), Probability: 8.57155102215746e-05
# N-gram: ('you', 'very', 'much', 'for', 'your'), Probability: 8.57055402509948e-05
# N-gram: ('very', 'much', 'for', 'your', 'help?'), Probability: 6.122573930080206e-06
# N-gram: ('much', 'for', 'your', 'help?', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('for', 'your', 'help?', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('your', 'help?', '</s>', '</s>', '</s>'), Probability: 6.123173763425059e-06
# N-gram: ('help?', '</s>', '</s>', '</s>', '</s>'), Probability: 0.00023874822469268817
# Final sentence probability: 9.313220909343027e-55
# Tokens with padding for max_n=5: ['<s>', '<s>', '<s>', '<s>', 'thank', 'you', 'very', 'much', 'for', 'your', 'help?', '</s>', '</s>', '</s>', '</s>']
# Final sentence probability with backoff: 3.8286604785820416e-20
#
# Top-5 Predictions for 'healp' (Laplace):
#   1. help? - Probability: 9.3132209093e-55
#   2. help - Probability: 2.3885610039e-56
#   3. heap - Probability: 2.3885610039e-56
#   4. heal - Probability: 2.3885610039e-56
#   5. helps - Probability: 2.3885610039e-56
#
# Top-5 Predictions for 'healp' (Stupid Backoff):
#   1. help? - Probability: 3.8286604786e-20
#   2. help - Probability: 1.8680265908e-20
#   3. helps - Probability: 4.7964400959e-23
#   4. heal - Probability: 1.1726979089e-23
#   5. heap - Probability: 7.3953922184e-25

# %%
print(f"Misspelled Word: {misspelled_word}")
print(f"Corrected Word: {corrected_word}")
# Out:
# Misspelled Word: healp
# Corrected Word: {'Laplace': 'help?', 'Stupid Backoff': 'help?'}
