# %% [markdown]
# # Lesson 6: Metaprompting with o1
#
# Optimizing to production is one of the biggest painpoints we've seen developers experience with working with LLMs - with so much guidance for prompt engineering, RAG and fine-tuning out there, figuring out which optimization you need to hill-climb on your evals can be a difficult problem to frame and solve.
#
# Luckily, it appears to be one of the use cases that `o1` is capable at. In this session we'll focus on how to use `o1-mini` to work with a set of evals to optimize our prompt for the task and improve score on our evals.

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>.
#
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
#
# <p> 📒 &nbsp; For more help, please see the <em>"Appendix – Tips, Help, and Download"</em> Lesson.</p>
#
# </div>

# %% [markdown]
# <p style="background-color:#f7fff8; padding:15px; border-width:3px; border-color:#e0f0e0; border-style:solid; border-radius:6px"> 🚨
# &nbsp; <b>Different Run Results:</b> The output generated by AI models can vary with each execution due to their dynamic, probabilistic nature. Don't be surprised if your results differ from those shown in the video.</p>

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Import OpenAI key
from helper import get_openai_api_key
openai_api_key = get_openai_api_key()

# %%
from openai import OpenAI
from IPython.display import display, Markdown
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
from functionDefinitions import TOOLS
import csv
import json
import os
import matplotlib.pyplot as plt

GPT_MODEL = 'gpt-4o-mini'
O1_MODEL = 'o1'

client = OpenAI(api_key=openai_api_key)

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
from redlines import Redlines
from IPython.display import display, Markdown

def compare_strings(string1, string2):
    # Create a Redlines object to compare the strings
    diff = Redlines(string1, string2)
    
    # Display the differences using Markdown
    display(Markdown(diff.output_markdown))

# Example usage
string_a = "This is the original text for comparison purposes."
string_b = "This is the modified text to compare for differences."

compare_strings(string_a, string_b)
# Out:
# This is the <span style='color:red;font-weight:700;text-decoration:line-through;'>original </span><span style='color:green;font-weight:700;'>modified </span>text <span style='color:green;font-weight:700;'>to compare </span>for <span style='color:red;font-weight:700;text-decoration:line-through;'>comparison purposes.</span><span style='color:green;font-weight:700;'>differences.</span>

# %% [markdown]
# ## Step 1: Generate 4o routine (prompt)
#
# We'll take the Flight Cancellation Policy that we have created and convert it to an LLM-based routine with the following prompt.
#
# This process is also a good use of O1, using a purely text document to create instructions and tools for an LLM to make use of. To dive deeper on this topic check out [this cookbook](https://cookbook.openai.com/examples/o1/using_reasoning_for_routine_generation).

# %%
with open('originalPolicy/flightCancellationsPolicy.md', 'r') as file:
    flight_cancellation_policy = file.read()
    print(flight_cancellation_policy)
# Out:
# # **Internal Flight Cancellations and Changes Policy**
#
# **Purpose**: This document serves as a detailed guide for internal support agents to handle flight cancellations and changes. The focus is on providing clear instructions, ensuring efficiency, consistency, and customer satisfaction during calls.
#
# **Note**: Always maintain a calm, empathetic tone while assisting customers, especially during stressful situations involving cancellations or major changes.
#
# ## **Table of Contents**
#
# 1. General Guidelines for Handling Customer Requests
# 2. Cancellations: Types and Policies
# 3. Changes: Types and Policies
# 4. Rebooking Guidelines
# 5. Compensation and Refund Rules
# 6. Special Cases
# 7. FAQs for Common Scenarios
#
# ### **1\. General Guidelines for Handling Customer Requests**
#
# * **Confirm Identity**: Verify the customer's identity by asking for their booking reference and any additional required details (e.g., name and flight number).
# * **Listen and Understand**: Clarify if the customer is looking to cancel, change, or inquire about compensation.
# * **Check the Ticket Type**: Determine if the ticket is non-refundable, refundable, or flexible. This will affect the available options.
# * **Be Empathetic**: Express empathy, especially when the customer is dealing with a disruption caused by the airline.
# * **Rely on Internal Data**: Only collect personal data from users (e.g. name, medical data, age, booking reference). All data regarding flights (such as fare type or refund amount) should be confirmed internally.
#
# ### **2\. Cancellations: Types and Policies**
#
# #### **2.1 Customer-Initiated Cancellations**
#
# * **Refundable Tickets**: Eligible for a full or partial refund based on cancellation timing.
#   * **Within 24 hours of booking**: Full refund guaranteed.
#   * **Beyond 24 hours**: Check the specific fare rules for applicable refund amounts.
# * **Non-Refundable Tickets**:
#   * **Flight Credit**: Offer flight credit for future use, subject to an administration fee.
#   * **Penalty Fee**: Advise customers of any penalty fee applicable.
#
# #### **2.2 Airline-Initiated Cancellations**
#
# * **Weather-Related Cancellations**:
#   * **Rebook Without Fees**: Allow the customer to rebook on the next available flight without any additional charges.
#   * **Refund Options**: If the rebooking option is not acceptable, offer a full refund.
# * **Mechanical Issues/Operational Changes**:
#   * **Rebooking Priority**: Give affected customers priority for rebooking.
#   * **Accommodation**: Offer hotel accommodation if the delay requires an overnight stay (for cancellations within 6 hours of departure).
#
# #### **2.3 No-Show Policy**
#
# * **No Refund for Non-Refundable Tickets**: No refunds are issued for no-shows; however, travel credits may be applied in certain cases.
# * **Partial Refund for Refundable Tickets**: Refund any taxes or airport fees where applicable.
#
# ### **3\. Changes: Types and Policies**
#
# #### **3.1 Customer-Initiated Changes**
#
# * **Same-Day Changes**:
#   * **Flexible Tickets**: Allow changes without any fees, subject to availability.
#   * **Non-Flexible Tickets**: Charge a change fee. The customer must also pay any fare difference.
# * **Changes in Advance**:
#   * **Within 7 Days of Departure**: Standard change fee applies.
#   * **Beyond 7 Days**: Lesser fee or free changes based on ticket type.
#
# #### **3.2 Airline-Initiated Changes**
#
# * **Schedule Changes**:
#   * **Minor Changes (Less than 2 Hours)**: Inform the customer of the new schedule and offer an alternative only upon request.
#   * **Major Changes (2+ Hours)**: Provide options to rebook, receive a full refund, or travel credit.
#
# ### **4\. Rebooking Guidelines**
#
# * **Priority Handling**: Rebook the customer on the next available flight operated by our airline first.
# * **Interline Agreements**: If no suitable options are available, check our interline partners to facilitate alternative connections.
# * **Upgrade Availability**: Offer a complimentary upgrade when an available flight is in a higher class but no economy seat is free.
#
# ### **5\. Compensation and Refund Rules**
#
# #### **5.1 Refund Processing**
#
# * **Refund Timeline**: Inform the customer that refunds will be processed within 7-10 business days for credit card payments and 14-20 business days for debit card payments.
# * **Refund Options**:
#   * **Original Payment Method**: Refunds will generally be credited back to the original method of payment.
#   * **Travel Credits**: Offer travel credits as an alternative, with a bonus percentage (e.g., 10%) as an incentive.
#
# #### **5.2 Compensation**
#
# * **EU/US Compensation Rules**: Depending on the region, inform customers of their right to compensation based on the length of delay and cause.
#   * **Meals and Accommodation**: If the delay exceeds four hours, provide meal vouchers or hotel accommodation.
#
# ### **6\. Special Cases**
#
# #### **6.1 Medical Emergencies**
#
# * **Flexible Cancellations**: Allow for full cancellation or flight credit when a medical certificate ID is provided.
# * **Flight Changes**: Waive change fees if the customer or immediate family member is ill.
#
# #### **6.2 Bereavement Cases**
#
# * **Special Flexibility**: Offer flexibility on cancellations or changes for bereavement. Request proper documentation if needed.
#
# #### **6.3 Group Bookings**
#
# * **Partial Cancellations**: Allow individual cancellations within a group booking, but advise that this may affect the group rate.
# * **Name Changes**: Permit one name change per passenger at no additional cost if made 7+ days before departure.
#
# #### **6.4 Unaccompanied Minors**
#
# * **Rebooking with Supervision**: Ensure proper supervision is arranged if changes are needed to flights involving unaccompanied minors.
# * **Priority for Minors**: Always prioritize getting unaccompanied minors on the next available flight.
#
# ### **7\. FAQs for Common Scenarios**
#
# **Q1: What if a customer’s connecting flight is affected?**
#
# * **Policy**: Always prioritize rebooking for missed connections caused by airline delays. Ensure the customer is protected for onward flights without additional fees.
#
# **Q2: How do I handle customers seeking upgrades after a cancellation?**
#
# * **Policy**: Offer upgrades based on availability if the original fare class is sold out. Otherwise, advise on the fare difference.
#
# **Q3: What if a customer needs to change a destination?**
#
# * **Policy**: Allow changes to a different destination, but advise the customer of any applicable fare differences and change fees.
#
# **Q4: What are the rules around rebooking for third-party bookings?**
#
# * **Policy**: Request that the customer contacts the original booking agent (e.g., travel agency, online booking platform) to make changes. Provide assistance if the booking is eligible for direct airline handling.
#
# **Q5: What should I do if the customer requests compensation for inconvenience?**
#
# * **Policy**: Assess eligibility based on the airline's compensation policy. Inform the customer about meal vouchers, accommodation, or monetary compensation if applicable.
#
# **Q6: How do I handle a situation where a customer’s preferred flight is fully booked?**
#
# * **Policy**: Offer the customer the next available option and place them on a waitlist for their preferred flight if possible. Consider offering an upgrade to a higher class if available.

# %%
CONVERSION_PROMPT = f"""
You are a helpful assistant tasked with taking an external facing help center article and converting it into a internal-facing programmatically executable routine optimized for an LLM. 
The LLM using this routine will be tasked with reading the policy, answering incoming questions from customers, and helping drive the case toward resolution.

Please follow these instructions:
1. **Review the customer service policy carefully** to ensure every step is accounted for. It is crucial not to skip any steps or policies.
2. **Organize the instructions into a logical, step-by-step order**, using the specified format. 
3. **Use the following format**:
   - **Main actions are numbered** (e.g., 1, 2, 3).
   - **Sub-actions are lettered** under their relevant main actions (e.g., 1a, 1b).
      **Sub-actions should start on new lines**
   - **Specify conditions using clear 'if...then...else' statements** (e.g., 'If the product was purchased within 30 days, then...').
   - **For instructions that require more information from the customer**, provide polite and professional prompts to ask for additional information.
   - **For actions that require data from external systems**, write a step to call a function using backticks for the function name (e.g., call the `check_delivery_date` function).
      - **If a step requires the customer service agent to take an action** (e.g., process a refund), generate a function call for this action (e.g., call the `process_refund` function).
      - **Only use the available set of functions that are defined below.
   - **If there is an action an assistant can perform on behalf of the user**, include a function call for this action (e.g., call the `change_email_address` function), and ensure the function is defined with its purpose and required parameters.
      - **Only use the available set of functions that are defined below.
   - **The step prior to case resolution should always be to ask if there is anything more you can assist with**.
   - **End with a final action for case resolution**: calling the `case_resolution` function should always be the final step.
4. **Ensure compliance** by making sure all steps adhere to company policies, privacy regulations, and legal requirements.
5. **Handle exceptions or escalations** by specifying steps for scenarios that fall outside the standard policy.
6. **Ensure coverage** by checking that all of the conditions covered in the policy are also covered in the routines

**Important**: Always wrap the functions you return in backticks i.e. `check_ticket_type`. Do not include the arguments to the functions.

Here are the currently available set of functions in JSON format: 
TOOLS: {TOOLS}

Please convert the following customer service policy into the formatted routine, ensuring it is easy to follow and execute programmatically. Ensure that you **only** use the functions provided and do **not** create net new functions."""

# %%
def generate_routine(policy):
    try:
        messages = [
            {
                "role": "user",
                "content": f"""
                    {CONVERSION_PROMPT}

                    POLICY:
                    {policy}
                """
            }
        ]

        response = client.chat.completions.create(
            model='o1-mini',
            messages=messages
        )
        

        return response.choices[0].message.content 
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
flight_cancellation_routine = generate_routine(flight_cancellation_policy)

# %%
display(Markdown(flight_cancellation_routine))
# Out:
# ```markdown
# 1. **Confirm Identity**
#    a. Prompt the customer for booking reference, full name, and flight number.
#       - `ask_clarification`
#    b. Call the `verify_identity` function.
#       - `verify_identity`
#    c. If identity verification fails, then:
#       - Prompt the customer to re-enter their details.
#          - `ask_clarification`
#       - Else:
#          - Escalate the case for further assistance.
#
# 2. **Listen and Understand Request**
#    a. Ask the customer to clarify their request.
#       - `ask_clarification`
#    b. If the customer wants to cancel, then:
#       - Proceed to step 3.
#    c. Else if the customer wants to change, then:
#       - Proceed to step 4.
#    d. Else if the customer inquires about compensation, then:
#       - Proceed to step 5.
#    e. Else:
#       - Ask for clarification again.
#          - `ask_clarification`
#
# 3. **Handle Cancellations**
#    a. Check if the cancellation is customer-initiated or airline-initiated.
#       - If customer-initiated, then:
#          i. Call `check_ticket_type`.
#             - `check_ticket_type`
#          ii. If the ticket is refundable, then:
#              - If cancellation is within 24 hours of booking, then:
#                 - Call `process_full_refund`.
#                    - `process_full_refund`
#              - Else:
#                 - Call `check_fare_rules`.
#                    - `check_fare_rules`
#                 - Call `process_partial_refund`.
#                    - `process_partial_refund`
#          iii. Else if the ticket is non-refundable, then:
#               - Call `offer_flight_credit`.
#                  - `offer_flight_credit`
#               - Advise the customer of applicable penalty fees.
#       - Else if airline-initiated, then:
#          i. If cancellation is weather-related, then:
#              - Call `rebook_without_fee`.
#                 - `rebook_without_fee`
#              - If rebooking is not acceptable, then:
#                 - Call `process_full_refund`.
#                    - `process_full_refund`
#          ii. Else if cancellation is due to mechanical issues or operational changes, then:
#              - Call `prioritize_missed_connections`.
#                 - `prioritize_missed_connections`
#              - If an overnight stay is required, then:
#                 - Call `offer_accommodation`.
#                    - `offer_accommodation`
#    b. If the customer is a no-show, then:
#       i. Call `check_ticket_type`.
#          - `check_ticket_type`
#       ii. If the ticket is non-refundable, then:
#           - Inform the customer that no refund is available.
#           - Offer travel credits if applicable.
#       iii. Else if the ticket is refundable, then:
#            - Call `process_partial_refund`.
#               - `process_partial_refund`
#
# 4. **Handle Changes**
#    a. Check if the change is customer-initiated or airline-initiated.
#       - If customer-initiated, then:
#          i. Determine if the change is same-day or in advance.
#             - If same-day, then:
#                - Call `check_ticket_type`.
#                   - `check_ticket_type`
#                - If the ticket is flexible, then:
#                   - Call `process_change_no_fee`.
#                      - `process_change_no_fee`
#                - Else:
#                   - Call `apply_change_fee`.
#                      - `apply_change_fee`
#                   - Advise the customer of any fare differences.
#             - Else if the change is in advance, then:
#                - If the change is within 7 days of departure, then:
#                   - Call `apply_change_fee`.
#                      - `apply_change_fee`
#                - Else:
#                   - Call `apply_lesser_change_fee`.
#                      - `apply_lesser_change_fee`
#       - Else if airline-initiated, then:
#          i. Determine if the change is minor or major.
#             - If minor (less than 2 hours), then:
#                - Inform the customer of the new schedule.
#                - Ask if they would like an alternative option.
#                   - `ask_clarification`
#             - Else if major (2+ hours), then:
#                - Offer options to rebook, receive a full refund, or obtain travel credit.
#                   - `ask_clarification`
#    b. After handling change fees and fare differences, proceed to rebooking.
#       - Proceed to step 6.
#
# 5. **Handle Compensation**
#    a. Call `check_compensation_eligibility`.
#       - `check_compensation_eligibility`
#    b. If the customer is eligible for compensation, then:
#       - Offer meal vouchers or hotel accommodation based on the delay duration.
#          - `offer_accommodation`
#    c. Else:
#       - Inform the customer of their ineligibility for compensation.
#
# 6. **Rebooking Guidelines**
#    a. Call `check_next_available_flight` to find the next available flight.
#       - `check_next_available_flight`
#    b. If a suitable flight is available with our airline, then:
#       - Call `rebook_without_fee`.
#          - `rebook_without_fee`
#    c. Else, if no suitable options are available, then:
#       - Call `check_interline_partners`.
#          - `check_interline_partners`
#       - If interline partners have available flights, then:
#          - Call `book_interline_flight`.
#             - `book_interline_flight`
#       - Else:
#          - Offer available upgrades based on fare class availability.
#             - `offer_available_upgrades`
#    d. After successful rebooking, ask if the customer would like an upgrade.
#       - `ask_clarification`
#
# 7. **Compensation and Refund Processing**
#    a. Inform the customer of the refund processing timeline based on their payment method.
#    b. Call `determine_refund_method`.
#       - `determine_refund_method`
#    c. If refund is to be processed to the original payment method, then:
#       - Call `process_refund`.
#          - `process_refund`
#    d. Else, if offering travel credits, then:
#       - Call `offer_travel_credit`.
#          - `offer_travel_credit`
#
# 8. **Special Cases**
#    a. If the customer cites a medical emergency, then:
#       - Call `process_flexible_cancellation`.
#          - `process_flexible_cancellation`
#       - Else, if a change is requested due to illness, then:
#          - Call `waive_change_fees`.
#             - `waive_change_fees`
#    b. If the customer is dealing with bereavement, then:
#       - Call `apply_bereavement_flexibility`.
#          - `apply_bereavement_flexibility`
#    c. If the booking is a group booking, then:
#       - If the customer wants to cancel part of the group, then:
#          - Call `process_partial_group_cancellation`.
#             - `process_partial_group_cancellation`
#       - If the customer requests a name change, then:
#          - If the change is made 7+ days before departure, then:
#             - Call `permit_name_change`.
#                - `permit_name_change`
#    d. If the booking involves unaccompanied minors, then:
#       - Call `arrange_supervision`.
#          - `arrange_supervision`
#       - Call `prioritize_minors_rebooking`.
#          - `prioritize_minors_rebooking`
#
# 9. **Ask if Anything More is Needed**
#    a. Prompt the customer to see if they need further assistance.
#       - `ask_clarification`
#
# 10. **Case Resolution**
#     a. Finalize and close the customer case with all resolution details.
#        - `case_resolution`
# ```

# %% [markdown]
# ### Data quality check
#
# We'll check that `o1-mini` has followed our instructions and used only the functions we provided.
#
# If it added additional ones, we'll need to write functions for them before proceeding.

# %%
import re
from collections import Counter

def compare_lists(a, b):
    # Create Counters for both lists
    counter_a = Counter(a)
    counter_b = Counter(b)
    
    # Find elements that are only in A or have a higher count in A
    diff_a = counter_a - counter_b
    # Find elements that are only in B or have a higher count in B
    diff_b = counter_b - counter_a
    
    # Report differences
    print("Items in A that are not in B (or more of in A):")
    for item, count in diff_a.items():
        print(f"{item}: {count}")

    print("\nItems in B that are not in A (or more of in B):")
    for item, count in diff_b.items():
        print(f"{item}: {count}")

def extract_function_names(text):
    # Use regex to match text between backticks and extract function names
    pattern = r'`(.*?)`'
    matches = re.findall(pattern, text)
    return matches

# Extract a unique list of the functions in the generated routine
function_names_from_o1 = set(extract_function_names(flight_cancellation_routine))

# Extract the list of TOOLs we provided the model
function_names_defined = [tool["function"]["name"] for tool in TOOLS if tool["type"] == "function"]

# Print the differences
## Items that are in A and not in B need functions written for them
## Items that are in B and not in A are fine, they are just unused in the routine the model has written
compare_lists(function_names_from_o1, function_names_defined)
# Out:
# Items in A that are not in B (or more of in A):
# : 1
# offer_travel_credit: 1
#
# Items in B that are not in A (or more of in B):
# provide_alternative_options: 1
# book_flight: 1
# apply_travel_credit: 1
# process_destination_change: 1
# assist_third_party_booking: 1
# assess_compensation_request: 1

# %% [markdown]
# ## Step 2: Evaluation
#
# Now that we have a routine generated with o1, we can run it against our evaluation suite and measure its accuracy.
#
# We'll start by creating an agent that is equipped with the policy and a list of tools. It will be given messages from an existing conversation and will be tasked with determining the next best action to take

# %%
def agent_response(transcript, policy, model):
    try:
        messages = [
            {
                "role": "system",
                "content": f"""
You are a customer service agent that is responsible for handling airline related issues. Below is the exact policy that you must follow to address the customer's issue.

POLICY:
{policy}
                """
            }
        ]

        messages.extend(transcript)
        response = client.chat.completions.create(
            model=model,
            messages=messages,
            tools=TOOLS,
            parallel_tool_calls=False,
        temperature=0)
        
        return response.choices[0].message 
    except Exception as e:
        print(f"An error occurred: {e}")
        print(messages)

# %% [markdown]
# We will process each row in parallel to reduce runtime and compare the function call + inputs that the model selects against our expected function + parameters.

# %%
import math 

def safe_str(value):
    return "" if (isinstance(value, float) and math.isnan(value)) else str(value)

def process_row(row_number,test_row,policy,model,iteration=0, verbose=False):
    # Extract variables from test_row
    context = test_row['context']
    request = test_row['request']
    full_name = test_row['full_name']
    booking_ref = test_row['booking_ref']
    flight_no = test_row['flight_no']
    ticket_type = test_row['ticket_type']
    fare_rules = safe_str(test_row['fare_rules'])
    medical_certificate = safe_str(test_row['medical_certificate'])
    refund_amount = safe_str(test_row['refund_amount'])
    expected_function = test_row['expected_function']
    expected_inputs_str = test_row['expected_inputs']
    expected_inputs = json.loads(expected_inputs_str)

    CUSTOMER_PROMPT = f"""<objective>You are a customer named {full_name} trying to resolve an issue with a customer service agent.
    Continue providing the information the agent requests so they can solve your issue.
    If you have the information in your *details* then use that. Otherwise, generate an appropriate answer.</objective>
    <details>
    Booking Reference: {booking_ref}
    Flight Number: {flight_no}
    {f"Medical Reference: {medical_certificate}" if medical_certificate else ""}
    Context: {context}
    Your initial request: {request}
    </details>
    <guidance>
    Remember that YOU are the customer.
    If the agent needs some information, that must come from you. 
    Do not ask the agent for information.
    </guidance>
    """

    # Initialize transcript
    transcript = [{"role": "user", "content": request}]
    if verbose:
        print(f'Starting request: {request}')
    
    # Initialize variables
    is_correct = False

    loop_count = 0
    while True:
        loop_count += 1
        if loop_count > 10:
            actual_function = None
            actual_inputs = None
            break
        # Call agent_response with the current transcript, policy, model
        response = agent_response(transcript, policy, GPT_MODEL)
        
        # Extract assistant message content and tool_calls
        if response:
            assistant_message_content = response.content
            tool_calls = response.tool_calls
        else:
            assistant_message_content = None
            tool_calls = None
        
        if not tool_calls:
            # Append assistant's message to transcript
            transcript.append({"role": "assistant", "content": assistant_message_content})
            
            # Get customer response
            customer_messages = [{"role": "system", "content": CUSTOMER_PROMPT}]
            customer_messages.extend(transcript)
            
            customer_response = client.chat.completions.create(model=GPT_MODEL, messages=customer_messages)
            
            # Append customer response to transcript
            transcript.append({"role": "user", "content": customer_response.choices[0].message.content})
            
            # Continue the loop
            continue
        else:
            #print(tool_calls)
            # There is a tool call
            tool_call = tool_calls[0]  # Assuming we're only interested in the first tool call
            function_name = tool_call.function.name
            arguments = json.loads(tool_call.function.arguments)
            
            if function_name == 'verify_identity':
                # Append assistant's message to transcript
                transcript.append(response)
                
                # Simulate the tool response
                tool_response = "True"
                
                # Append the tool response to transcript
                transcript.append({"role": "tool", "content": tool_response, "tool_call_id": tool_call.id})
                
                # Continue the loop
                continue
            elif function_name == 'ask_clarification':
                # Take the 'prompt' from arguments and use it as assistant message
                clarification_prompt = arguments.get('prompt')
                
                # Append assistant's clarification message
                transcript.append({"role": "assistant", "content": clarification_prompt})
                
                # Get customer response
                customer_messages = [{"role": "system", "content": CUSTOMER_PROMPT}]
                customer_messages.extend(transcript)
                
                customer_response = client.chat.completions.create(model=GPT_MODEL, messages=customer_messages)
                
                # Append customer response to transcript
                transcript.append({"role": "user", "content": customer_response.choices[0].message.content})
                
                # Continue the loop
                continue
            elif function_name == 'check_ticket_type':
                # Append assistant's message to transcript
                transcript.append(response)
                
                tool_response = f'Ticket type: {ticket_type}\nFare rules: {fare_rules}'
                
                # Append the tool response to transcript
                transcript.append({"role": "tool", "content": tool_response, "tool_call_id": tool_call.id})
                
                # Continue the loop
                continue
            elif function_name == 'check_fare_rules':
                # Append assistant's message to transcript
                transcript.append(response)
                
                tool_response = f'Ticket type: {ticket_type}\nFare rules: {fare_rules}'

                if fare_rules == 'partial_refund':
                    tool_response += f'\nRefund amount: {refund_amount}'
                
                # Append the tool response to transcript
                transcript.append({"role": "tool", "content": tool_response, "tool_call_id": tool_call.id})
                
                # Continue the loop
                continue
            elif function_name == 'get_refund_amount':
                # Append assistant's message to transcript
                transcript.append(response)
                
                tool_response = f'Refund amount: {refund_amount}'
                
                # Append the tool response to transcript
                transcript.append({"role": "tool", "content": tool_response, "tool_call_id": tool_call.id})
                
                # Continue the loop
                continue
            elif function_name == 'check_next_available_flight':
                # Append assistant's message to transcript
                transcript.append(response)
                
                # simulating the tool response
                tool_response = f'Next available flight: LMG091 at 10:00 AM Tomorrow'
                
                # Append the tool response to transcript
                transcript.append({"role": "tool", "content": tool_response, "tool_call_id": tool_call.id})
                
                # Continue the loop
                continue
            elif function_name == 'provide_alternative_options':
                # Append assistant's message to transcript
                transcript.append(response)
                
                # simulating the tool response
                tool_response = f'Next available flight: FR9876 at 5:00 PM Tomorrow'
                
                # Append the tool response to transcript
                transcript.append({"role": "tool", "content": tool_response, "tool_call_id": tool_call.id})
                
                # Continue the loop
                continue
            else:
                if verbose:
                    print('Got a successful function call')
                # Stop and compare function call and arguments with expected_function and expected_inputs
                transcript.append(response)
                actual_function = function_name
                actual_inputs = arguments
                is_correct = (actual_function == expected_function) and (str(actual_inputs) == str(expected_inputs))
                
                # Break the loop
                break
    
    # Return the results
    return {
        'request': request,
        'context': context,
        'expected_function': expected_function,
        'expected_inputs': expected_inputs,
        'actual_function': actual_function,
        'actual_inputs': actual_inputs,
        'is_correct': is_correct,
        'transcript': transcript
    }

# added post-filming to address transcript size
def filter_messages(message_list):
    messages = []
    for item in message_list:
        # Convert the item to a string and check if 'ChatCompletionMessage' is in it.
        if 'ChatCompletionMessage' in str(item):
            #print(item)
            message = {"role": "assistant",
                       "tool_call": {
                           "name": item.tool_calls[0].function.name,
                           "arguments": item.tool_calls[0].function.arguments
                       }
                      }
            messages.append(message)
        else:
            messages.append(item)
    return messages


def evaluate_function_calls(df, policy, model, i=0, verbose=False):
    records = []

    # Use ThreadPoolExecutor to process rows in parallel
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_row, row_number, row, policy, model, i, verbose): row_number for row_number, row in df.iterrows()}
        for future in futures:
            record = future.result()
            records.append(record)


    df = pd.DataFrame(records)
    df['cleaned_transcript'] = df['transcript'].apply(filter_messages)
    total_accuracy = df['is_correct'].mean()
    return df, total_accuracy

# %% [markdown]
# Let's take a look at the results

# %%
eval_df = pd.read_csv('evals/policyEvals.csv')
eval_df.head()
# Out:
#    ID  \
# 0   0
# 1   1
# 2   2
# 3   3
# 4   4
#
#                                                                                     context  \
# 0                    I want to cancel my flight as I am initiating the cancellation myself.
# 1                                           I want to change my flight to a different date.
# 2  I want to request a refund because my flight was canceled by the airline due to weather.
# 3                              I want to cancel my flight but I think it is non-refundable.
# 4                                I want to cancel my flight and I believe it is refundable.
#
#                                                         request  \
# 0                     I would like to cancel my flight, please.
# 1  I'd like to initiate a change to my flight for a later date.
# 2   My flight was canceled by the airline, and I want a refund.
# 3                    I want to cancel my non-refundable ticket.
# 4                        I want to cancel my refundable ticket.
#
#        full_name booking_ref flight_no       expected_function  \
# 0       John Doe      ABC123    XYZ789  process_partial_refund
# 1     Jane Smith      DEF456    XYZ123        apply_change_fee
# 2   Emma Johnson      GHI789    ABC123     process_full_refund
# 3  Michael Brown      JKL012    DEF456     offer_flight_credit
# 4    Sarah Brown      MNO345    STU678  process_partial_refund
#
#                                       expected_inputs    ticket_type  \
# 0  {"booking_reference":"ABC123","refund_amount":198}     refundable
# 1                      {"booking_reference":"DEF456"}  nonrefundable
# 2                      {"booking_reference":"GHI789"}     refundable
# 3                      {"booking_reference":"JKL012"}  nonrefundable
# 4   {"booking_reference":"MNO345","refund_amount":65}     refundable
#
#        fare_rules medical_certificate  refund_amount
# 0  partial_refund                 NaN          198.0
# 1             NaN                 NaN            NaN
# 2     full_refund                 NaN            NaN
# 3             NaN                 NaN            NaN
# 4  partial_refund                 NaN           65.0

# %%
from termcolor import colored

def display_row(index):
    eval_row = eval_df.iloc[index]
    df_row = df.iloc[index][["actual_function", "actual_inputs", "is_correct", "cleaned_transcript"]]
    transcript_list = df_row["cleaned_transcript"]

    print("Eval DataFrame Row:")
    print(eval_row)
    print("\nDataFrame Columns:")
    print("actual_function:", df_row["actual_function"])
    print("actual_inputs:", df_row["actual_inputs"])
    print("is_correct:", df_row["is_correct"])
    print("transcript:")
    for entry in transcript_list:
        role = entry["role"] if isinstance(entry, dict) else getattr(entry, "role", None)
        color = "blue" if role == "user" else "red"
        print(colored(str(entry), color))

# %%
df, accuracy = evaluate_function_calls(eval_df, flight_cancellation_routine, GPT_MODEL)

# Display the accuracy as a mini header
display(Markdown(f"### Accuracy: {accuracy:.2%}"))

display(df)
# Out:
# ### Accuracy: 64.71%
#                                                                       request  \
# 0                                   I would like to cancel my flight, please.
# 1                I'd like to initiate a change to my flight for a later date.
# 2                 My flight was canceled by the airline, and I want a refund.
# 3                                  I want to cancel my non-refundable ticket.
# 4                                      I want to cancel my refundable ticket.
# 5                 I missed my connecting flight because of the airline delay.
# 6   I want to know if I am eligible for compensation because of a long delay.
# 7                                           I would like to rebook my flight.
# 8                  I want to cancel my flight because of a medical emergency.
# 9              I would like to change the passenger name on my group booking.
# 10          The airline canceled my flight, and I need a hotel for the night.
# 11                         I need to change my flight within the next 7 days.
# 12               I want to change my non-flexible flight to a different date.
# 13         The airline canceled my flight due to weather. Can I get rebooked?
# 14                              I need a refund for my non-refundable flight.
# 15                     I need a refund for a flight I booked a few hours ago.
# 16      I missed my connecting flight because of a delay. Can I get rebooked?
#
#                                                                                                                 context  \
# 0                                                I want to cancel my flight as I am initiating the cancellation myself.
# 1                                                                       I want to change my flight to a different date.
# 2                              I want to request a refund because my flight was canceled by the airline due to weather.
# 3                                                          I want to cancel my flight but I think it is non-refundable.
# 4                                                            I want to cancel my flight and I believe it is refundable.
# 5                     I want to address the issue of missing my connecting flight due to a delay caused by the airline.
# 6                                        I want to know if I can receive compensation due to a long delay on my flight.
# 7                                          I want to rebook my flight, and I have provided my details for verification.
# 8                                                                I want to cancel my flight due to a medical emergency.
# 9                                               I want to change the name of one of the passengers in my group booking.
# 10                                                I want to find a hotel because my flight was canceled by the airline.
# 11          I want to change my flight because it's within the next week and I hope I can do it without any extra fees.
# 12                       I want to change my flight date, but I know my ticket is non-flexible which might incur a fee.
# 13                             I want to get rebooked on a flight since my original flight was canceled due to weather.
# 14                                                         I want to cancel my flight but I think it is non-refundable.
# 15  I want to get a refund for a recently booked flight and I have provided the necessary details to verify my booking.
# 16                       I want to get rebooked on another flight because I missed my connecting flight due to a delay.
#
#                  expected_function  \
# 0           process_partial_refund
# 1                 apply_change_fee
# 2              process_full_refund
# 3              offer_flight_credit
# 4           process_partial_refund
# 5    prioritize_missed_connections
# 6   check_compensation_eligibility
# 7            process_change_no_fee
# 8    process_flexible_cancellation
# 9               permit_name_change
# 10             offer_accommodation
# 11           process_change_no_fee
# 12                apply_change_fee
# 13              rebook_without_fee
# 14             offer_flight_credit
# 15             process_full_refund
# 16   prioritize_missed_connections
#
#                                                      expected_inputs  \
# 0              {'booking_reference': 'ABC123', 'refund_amount': 198}
# 1                                    {'booking_reference': 'DEF456'}
# 2                                    {'booking_reference': 'GHI789'}
# 3                                    {'booking_reference': 'JKL012'}
# 4               {'booking_reference': 'MNO345', 'refund_amount': 65}
# 5                                    {'booking_reference': 'PQR678'}
# 6                                    {'booking_reference': 'STU901'}
# 7            {'booking_reference': 'VWX234', 'new_flight': 'LMG091'}
# 8   {'booking_reference': 'YZA567', 'medical_certificate': 'MC1234'}
# 9                                    {'booking_reference': 'BCD890'}
# 10                                   {'booking_reference': 'EFG123'}
# 11           {'booking_reference': 'GHI123', 'new_flight': 'LMG091'}
# 12                                   {'booking_reference': 'JKL234'}
# 13                                   {'booking_reference': 'MNO345'}
# 14                                   {'booking_reference': 'PQR567'}
# 15                                   {'booking_reference': 'STU678'}
# 16                                   {'booking_reference': 'XYZ901'}
#
#                    actual_function  \
# 0           process_partial_refund
# 1                 apply_change_fee
# 2               rebook_without_fee
# 3              offer_flight_credit
# 4           process_partial_refund
# 5    prioritize_missed_connections
# 6   check_compensation_eligibility
# 7            process_change_no_fee
# 8    process_flexible_cancellation
# 9               permit_name_change
# 10             offer_accommodation
# 11           process_change_no_fee
# 12                apply_change_fee
# 13              rebook_without_fee
# 14             offer_flight_credit
# 15             process_full_refund
# 16              rebook_without_fee
#
#                                                          actual_inputs  \
# 0                {'booking_reference': 'ABC123', 'refund_amount': 198}
# 1                                      {'booking_reference': 'DEF456'}
# 2                                      {'booking_reference': 'GHI789'}
# 3                                      {'booking_reference': 'JKL012'}
# 4                {'booking_reference': 'MNO345', 'refund_amount': 100}
# 5                                      {'booking_reference': 'PQR678'}
# 6                                      {'booking_reference': 'STU901'}
# 7                                      {'booking_reference': 'VWX234'}
# 8   {'booking_reference': 'YZA567', 'medical_certificate': 'Provided'}
# 9                                      {'booking_reference': 'BCD890'}
# 10                                     {'booking_reference': 'EFG123'}
# 11                                     {'booking_reference': 'GHI123'}
# 12                                     {'booking_reference': 'JKL234'}
# 13                                     {'booking_reference': 'MNO345'}
# 14                                     {'booking_reference': 'PQR567'}
# 15                                     {'booking_reference': 'STU678'}
# 16                                     {'booking_reference': 'XYZ901'}
#
#     is_correct  \
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
# 6         True
# 7        False
# 8        False
# 9         True
# 10        True
# 11       False
# 12        True
# 13        True
# 14        True
# 15        True
# 16       False
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          transcript  \
# 0   [{'role': 'user', 'content': 'I would like to cancel my flight, please.'}, {'role': 'assistant', 'content': 'Could you please provide your booking reference, full name, and flight number for verification?'}, {'role': 'user', 'content': 'Sure! My booking reference is ABC123, and my flight number is XYZ789. My full name is John Doe.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_4mIrGV3sHbikaXle9C8U0F5n', function=Function(arguments='{"booking_reference":"ABC123","full_name":"John Doe","flight_number":"XYZ789"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_4mIrGV3sHbikaXle9C8U0F5n'}, {'role': 'assistant', 'content': 'Thank you for verifying your identity, John Doe. Now, could you please clarify if this cancellation is customer-initiated or airline-initiated?'}, {'role': 'user', 'content': 'This cancellation is customer-initiated, as I am the one requesting it.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_zuuuzZhtq9iMbdzxBiusvqBg', function=Function(arguments='{"booking_reference":"ABC123"}', name='check_ticket_type'), type='function')]), {'role': 'tool', 'content': 'Ticket type: refundable
# Fare rules: partial_refund', 'tool_call_id': 'call_zuuuzZhtq9iMbdzxBiusvqBg'}, ChatCompletionMessage(content='Since your ticket is refundable, I will proceed with the cancellation. Since the cancellation is not within 24 hours of booking, I will check the fare rules to determine the applicable refund amount. \n\nLet me check the fare rules for you.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_5E0tTJTlipWB7HDczJxxrhIa', function=Function(arguments='{"booking_reference":"ABC123"}', name='check_fare_rules'), type='function')]), {'role': 'tool', 'content': 'Ticket type: refundable
# Fare rules: partial_refund
# Refund amount: 198.0', 'tool_call_id': 'call_5E0tTJTlipWB7HDczJxxrhIa'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_KhuqvR7T3xwATuOiSWRQjpBa', function=Function(arguments='{"booking_reference":"ABC123","refund_amount":198}', name='process_partial_refund'), type='function')])]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'role': 'user', 'content': 'I'd like to initiate a change to my flight for a later date.'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide me with your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is DEF456, my name is Jane Smith, and my flight number is XYZ123.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_4qEzmBJezYK2wjaD9nqp3PqE', function=Function(arguments='{"booking_reference":"DEF456","full_name":"Jane Smith","flight_number":"XYZ123"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_4qEzmBJezYK2wjaD9nqp3PqE'}, {'role': 'assistant', 'content': 'Thank you, Jane Smith, for confirming your identity. Now, could you please clarify the details of the change you would like to make to your flight?'}, {'role': 'user', 'content': 'I would like to change my flight to a later date. I am flexible with the dates, so I'm open to options that are available.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_qLZOS7fPMF5BmULI5Cl8GXic', function=Function(arguments='{"booking_reference":"DEF456"}', name='check_ticket_type'), type='function')]), {'role': 'tool', 'content': 'Ticket type: nonrefundable
# Fare rules: ', 'tool_call_id': 'call_qLZOS7fPMF5BmULI5Cl8GXic'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_O6Qrc2zTQoPdi4BVL7DQAXcF', function=Function(arguments='{"booking_reference":"DEF456"}', name='apply_change_fee'), type='function')])]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'role': 'user', 'content': 'My flight was canceled by the airline, and I want a refund.'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide me with your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is GHI789, my full name is Emma Johnson, and my flight number is ABC123.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_aMJx1p4bprlCes1kGzRmYmWM', function=Function(arguments='{"booking_reference":"GHI789","full_name":"Emma Johnson","flight_number":"ABC123"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_aMJx1p4bprlCes1kGzRmYmWM'}, ChatCompletionMessage(content='Thank you for confirming your identity, Emma. Since your flight was canceled by the airline, I will proceed to handle your refund request.\n\nFirst, I need to check if the cancellation was weather-related or due to other operational issues. Please hold on for a moment.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_uB63dhWHExAbOike5ZcQa5EF', function=Function(arguments='{"booking_reference":"GHI789"}', name='rebook_without_fee'), type='function')])]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'role': 'user', 'content': 'I want to cancel my non-refundable ticket.'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide me with your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'Sure, my booking reference is JKL012. My name is Michael Brown, and my flight number is DEF456.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_iWVBoFi2d0L2Ca2J9QFagWio', function=Function(arguments='{"booking_reference":"JKL012","full_name":"Michael Brown","flight_number":"DEF456"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_iWVBoFi2d0L2Ca2J9QFagWio'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_oBN5IvZCwmqUGH6MwkvTZufL', function=Function(arguments='{"booking_reference":"JKL012"}', name='check_ticket_type'), type='function')]), {'role': 'tool', 'content': 'Ticket type: nonrefundable
# Fare rules: ', 'tool_call_id': 'call_oBN5IvZCwmqUGH6MwkvTZufL'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_SRlls36QTG4gq8OImBupAEPr', function=Function(arguments='{"booking_reference":"JKL012"}', name='offer_flight_credit'), type='function')])]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [{'role': 'user', 'content': 'I want to cancel my refundable ticket.'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is MNO345, my name is Sarah Brown, and my flight number is STU678.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_25Kas134Bl9AZw6a4Wd7dStk', function=Function(arguments='{"booking_reference":"MNO345","full_name":"Sarah Brown","flight_number":"STU678"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_25Kas134Bl9AZw6a4Wd7dStk'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_6i4pYUYai1KFYfHa19vR5IHm', function=Function(arguments='{"booking_reference":"MNO345"}', name='check_ticket_type'), type='function')]), {'role': 'tool', 'content': 'Ticket type: refundable
# Fare rules: partial_refund', 'tool_call_id': 'call_6i4pYUYai1KFYfHa19vR5IHm'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_UT75Ra6R0Etd1UM8FO89Quvn', function=Function(arguments='{"booking_reference":"MNO345","refund_amount":100}', name='process_partial_refund'), type='function')])]
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'role': 'user', 'content': 'I missed my connecting flight because of the airline delay.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'Sure! My booking reference is PQR678, my full name is David White, and my flight number is LMN789.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_dP9TUZCkPHb1Om98OgZX1ppb', function=Function(arguments='{"booking_reference":"PQR678","full_name":"David White","flight_number":"LMN789"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_dP9TUZCkPHb1Om98OgZX1ppb'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_jLMYefhkVRlSRFz4HGiycAVo', function=Function(arguments='{"booking_reference":"PQR678"}', name='prioritize_missed_connections'), type='function')])]
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'role': 'user', 'content': 'I want to know if I am eligible for compensation because of a long delay.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can verify your identity?'}, {'role': 'user', 'content': 'My booking reference is STU901, my flight number is ABC789, and my name is Jessica Green.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_Whzs9ab1n89ehdJPuCnzM6GR', function=Function(arguments='{"booking_reference":"STU901","full_name":"Jessica Green","flight_number":"ABC789"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_Whzs9ab1n89ehdJPuCnzM6GR'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_wUQmOb27977cahyrDwOdzjkB', function=Function(arguments='{"booking_reference":"STU901"}', name='check_compensation_eligibility'), type='function')])]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'role': 'user', 'content': 'I would like to rebook my flight.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'My booking reference is VWX234, my flight number is XYZ345, and my name is Lucas Brown.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_WC4gLW8ppaWO5FHtuqVseZDl', function=Function(arguments='{"booking_reference":"VWX234","full_name":"Lucas Brown","flight_number":"XYZ345"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_WC4gLW8ppaWO5FHtuqVseZDl'}, {'role': 'assistant', 'content': 'Could you please clarify if you would like to change your flight to a different date or time, or if you are looking for an alternative flight due to a cancellation or delay?'}, {'role': 'user', 'content': 'I would like to change my flight to a different date.'}, {'role': 'assistant', 'content': 'Is this change customer-initiated or airline-initiated? Additionally, is the change for the same day or in advance?'}, {'role': 'user', 'content': 'I would like to change my flight for a date in advance.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_oLdWhkA6iapf7l6i4UVS93o8', function=Function(arguments='{"booking_reference":"VWX234"}', name='check_ticket_type'), type='function')]), {'role': 'tool', 'content': 'Ticket type: flexible
# Fare rules: ', 'tool_call_id': 'call_oLdWhkA6iapf7l6i4UVS93o8'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_0qztsv9K1RGnOf6NbaKUWEgp', function=Function(arguments='{"booking_reference":"VWX234"}', name='process_change_no_fee'), type='function')])]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'role': 'user', 'content': 'I want to cancel my flight because of a medical emergency.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number to confirm your identity?'}, {'role': 'user', 'content': 'Sure, my booking reference is YZA567, my full name is Laura Adams, and my flight number is PQR678.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_b0SaYU7uRmzHYuGKuGHiuCF5', function=Function(arguments='{"booking_reference":"YZA567","full_name":"Laura Adams","flight_number":"PQR678"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_b0SaYU7uRmzHYuGKuGHiuCF5'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_jaH9ANvw3dwLFBgP9hZaPr92', function=Function(arguments='{"booking_reference":"YZA567","medical_certificate":"Provided"}', name='process_flexible_cancellation'), type='function')])]
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'role': 'user', 'content': 'I would like to change the passenger name on my group booking.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'Sure! My booking reference is BCD890, and my flight number is QRS123. The passenger name I would like to change is [insert passenger's name].'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_9K6lLMaNdfufiP4Kg9pe0pCh', function=Function(arguments='{"booking_reference":"BCD890","full_name":"","flight_number":"QRS123"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_9K6lLMaNdfufiP4Kg9pe0pCh'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_3vigLZVucT82Cbl9jMMuicdV', function=Function(arguments='{"booking_reference":"BCD890"}', name='permit_name_change'), type='function')])]
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'role': 'user', 'content': 'The airline canceled my flight, and I need a hotel for the night.'}, {'role': 'assistant', 'content': 'I can assist you with that. First, I need to confirm your identity. Please provide me with your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is EFG123, my flight number is XYZ789, and my name is Ryan Walker.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ic1E6YGXSkxrRiJLjICnpJg9', function=Function(arguments='{"booking_reference":"EFG123","full_name":"Ryan Walker","flight_number":"XYZ789"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_ic1E6YGXSkxrRiJLjICnpJg9'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_1VBmDeyB21ZR2f8s79Sdy7G9', function=Function(arguments='{"booking_reference":"EFG123"}', name='offer_accommodation'), type='function')])]
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [{'role': 'user', 'content': 'I need to change my flight within the next 7 days.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'My booking reference is GHI123, my flight number is PQR789, and my name is Lisa Brown.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_mC3jtLHnjbI9HnjnbbNJoRwy', function=Function(arguments='{"booking_reference":"GHI123","full_name":"Lisa Brown","flight_number":"PQR789"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_mC3jtLHnjbI9HnjnbbNJoRwy'}, {'role': 'assistant', 'content': 'Could you please clarify what specific change you would like to make to your flight?'}, {'role': 'user', 'content': 'I would like to change my flight to a different date. Ideally, I hope to do this without incurring any extra fees, since it’s within the next week.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_F5bIu8wi2j5Av7zLYtGguIwC', function=Function(arguments='{"booking_reference":"GHI123"}', name='check_ticket_type'), type='function')]), {'role': 'tool', 'content': 'Ticket type: flexible
# Fare rules: ', 'tool_call_id': 'call_F5bIu8wi2j5Av7zLYtGguIwC'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_4Ne8YA1cXY1bYcBgy3cSqDbN', function=Function(arguments='{"booking_reference":"GHI123"}', name='process_change_no_fee'), type='function')])]
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'role': 'user', 'content': 'I want to change my non-flexible flight to a different date.'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is JKL234, my name is Robert Williams, and my flight number is STU567.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_c1EnRaieXQZYMJvCFeA7NkMC', function=Function(arguments='{"booking_reference":"JKL234","full_name":"Robert Williams","flight_number":"STU567"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_c1EnRaieXQZYMJvCFeA7NkMC'}, {'role': 'assistant', 'content': 'Could you please clarify the new date you would like to change your flight to?'}, {'role': 'user', 'content': 'I would like to change my flight to next Friday, if possible.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_FEAOFf3rwSbKHm2u7JGqJiO9', function=Function(arguments='{"booking_reference":"JKL234"}', name='check_ticket_type'), type='function')]), {'role': 'tool', 'content': 'Ticket type: nonrefundable
# Fare rules: ', 'tool_call_id': 'call_FEAOFf3rwSbKHm2u7JGqJiO9'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_1xL9eoE2eF2J3aIYCCDSi1fX', function=Function(arguments='{"booking_reference":"JKL234"}', name='apply_change_fee'), type='function')])]
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'role': 'user', 'content': 'The airline canceled my flight due to weather. Can I get rebooked?'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is MNO345, my name is Emma Johnson, and my flight number is XYZ123.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ojbWnPYaa8xA5md0Gi4DeQNy', function=Function(arguments='{"booking_reference":"MNO345","full_name":"Emma Johnson","flight_number":"XYZ123"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_ojbWnPYaa8xA5md0Gi4DeQNy'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_MIbMJX3GTKJa0fuSanl3eatI', function=Function(arguments='{"booking_reference":"MNO345"}', name='rebook_without_fee'), type='function')])]
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [{'role': 'user', 'content': 'I need a refund for my non-refundable flight.'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide me with your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is PQR567, my full name is David White, and my flight number is XYZ456.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_7uYCkjzzDB1x3Vo341TtNxP8', function=Function(arguments='{"booking_reference":"PQR567","full_name":"David White","flight_number":"XYZ456"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_7uYCkjzzDB1x3Vo341TtNxP8'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_Byi5GH8STby21zxanVyoI4LL', function=Function(arguments='{"booking_reference":"PQR567"}', name='offer_flight_credit'), type='function')])]
# ...
# 7                                               [{'role': 'user', 'content': 'I would like to rebook my flight.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'My booking reference is VWX234, my flight number is XYZ345, and my name is Lucas Brown.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"VWX234","full_name":"Lucas Brown","flight_number":"XYZ345"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_WC4gLW8ppaWO5FHtuqVseZDl'}, {'role': 'assistant', 'content': 'Could you please clarify if you would like to change your flight to a different date or time, or if you are looking for an alternative flight due to a cancellation or delay?'}, {'role': 'user', 'content': 'I would like to change my flight to a different date.'}, {'role': 'assistant', 'content': 'Is this change customer-initiated or airline-initiated? Additionally, is the change for the same day or in advance?'}, {'role': 'user', 'content': 'I would like to change my flight for a date in advance.'}, {'role': 'assistant', 'tool_call': {'name': 'check_ticket_type', 'arguments': '{"booking_reference":"VWX234"}'}}, {'role': 'tool', 'content': 'Ticket type: flexible
# Fare rules: ', 'tool_call_id': 'call_oLdWhkA6iapf7l6i4UVS93o8'}, {'role': 'assistant', 'tool_call': {'name': 'process_change_no_fee', 'arguments': '{"booking_reference":"VWX234"}'}}]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [{'role': 'user', 'content': 'I want to cancel my flight because of a medical emergency.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number to confirm your identity?'}, {'role': 'user', 'content': 'Sure, my booking reference is YZA567, my full name is Laura Adams, and my flight number is PQR678.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"YZA567","full_name":"Laura Adams","flight_number":"PQR678"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_b0SaYU7uRmzHYuGKuGHiuCF5'}, {'role': 'assistant', 'tool_call': {'name': 'process_flexible_cancellation', 'arguments': '{"booking_reference":"YZA567","medical_certificate":"Provided"}'}}]
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'role': 'user', 'content': 'I would like to change the passenger name on my group booking.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'Sure! My booking reference is BCD890, and my flight number is QRS123. The passenger name I would like to change is [insert passenger's name].'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"BCD890","full_name":"","flight_number":"QRS123"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_9K6lLMaNdfufiP4Kg9pe0pCh'}, {'role': 'assistant', 'tool_call': {'name': 'permit_name_change', 'arguments': '{"booking_reference":"BCD890"}'}}]
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [{'role': 'user', 'content': 'The airline canceled my flight, and I need a hotel for the night.'}, {'role': 'assistant', 'content': 'I can assist you with that. First, I need to confirm your identity. Please provide me with your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is EFG123, my flight number is XYZ789, and my name is Ryan Walker.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"EFG123","full_name":"Ryan Walker","flight_number":"XYZ789"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_ic1E6YGXSkxrRiJLjICnpJg9'}, {'role': 'assistant', 'tool_call': {'name': 'offer_accommodation', 'arguments': '{"booking_reference":"EFG123"}'}}]
# 11                                                                                                                                                                                                                                                                           [{'role': 'user', 'content': 'I need to change my flight within the next 7 days.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'My booking reference is GHI123, my flight number is PQR789, and my name is Lisa Brown.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"GHI123","full_name":"Lisa Brown","flight_number":"PQR789"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_mC3jtLHnjbI9HnjnbbNJoRwy'}, {'role': 'assistant', 'content': 'Could you please clarify what specific change you would like to make to your flight?'}, {'role': 'user', 'content': 'I would like to change my flight to a different date. Ideally, I hope to do this without incurring any extra fees, since it’s within the next week.'}, {'role': 'assistant', 'tool_call': {'name': 'check_ticket_type', 'arguments': '{"booking_reference":"GHI123"}'}}, {'role': 'tool', 'content': 'Ticket type: flexible
# Fare rules: ', 'tool_call_id': 'call_F5bIu8wi2j5Av7zLYtGguIwC'}, {'role': 'assistant', 'tool_call': {'name': 'process_change_no_fee', 'arguments': '{"booking_reference":"GHI123"}'}}]
# 12                                                                                                                                                                                                                                                                                                                               [{'role': 'user', 'content': 'I want to change my non-flexible flight to a different date.'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is JKL234, my name is Robert Williams, and my flight number is STU567.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"JKL234","full_name":"Robert Williams","flight_number":"STU567"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_c1EnRaieXQZYMJvCFeA7NkMC'}, {'role': 'assistant', 'content': 'Could you please clarify the new date you would like to change your flight to?'}, {'role': 'user', 'content': 'I would like to change my flight to next Friday, if possible.'}, {'role': 'assistant', 'tool_call': {'name': 'check_ticket_type', 'arguments': '{"booking_reference":"JKL234"}'}}, {'role': 'tool', 'content': 'Ticket type: nonrefundable
# Fare rules: ', 'tool_call_id': 'call_FEAOFf3rwSbKHm2u7JGqJiO9'}, {'role': 'assistant', 'tool_call': {'name': 'apply_change_fee', 'arguments': '{"booking_reference":"JKL234"}'}}]
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'role': 'user', 'content': 'The airline canceled my flight due to weather. Can I get rebooked?'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is MNO345, my name is Emma Johnson, and my flight number is XYZ123.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"MNO345","full_name":"Emma Johnson","flight_number":"XYZ123"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_ojbWnPYaa8xA5md0Gi4DeQNy'}, {'role': 'assistant', 'tool_call': {'name': 'rebook_without_fee', 'arguments': '{"booking_reference":"MNO345"}'}}]
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'role': 'user', 'content': 'I need a refund for my non-refundable flight.'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide me with your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is PQR567, my full name is David White, and my flight number is XYZ456.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"PQR567","full_name":"David White","flight_number":"XYZ456"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_7uYCkjzzDB1x3Vo341TtNxP8'}, {'role': 'assistant', 'tool_call': {'name': 'offer_flight_credit', 'arguments': '{"booking_reference":"PQR567"}'}}]
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'role': 'user', 'content': 'I need a refund for a flight I booked a few hours ago.'}, {'role': 'assistant', 'content': 'To assist you with your refund request, I need to confirm your identity. Please provide me with your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is STU678, and my flight number is ABC345. My full name is Sarah Green.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"STU678","full_name":"Sarah Green","flight_number":"ABC345"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_Dpg1zAh6ZAsprpnMPdZRccyY'}, {'role': 'assistant', 'tool_call': {'name': 'check_ticket_type', 'arguments': '{"booking_reference":"STU678"}'}}, {'role': 'tool', 'content': 'Ticket type: refundable
# Fare rules: full_refund', 'tool_call_id': 'call_y61EWsCoAweb7pOEgtLJFxQ3'}, {'role': 'assistant', 'tool_call': {'name': 'process_full_refund', 'arguments': '{"booking_reference":"STU678"}'}}]
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'role': 'user', 'content': 'I missed my connecting flight because of a delay. Can I get rebooked?'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number to verify your identity?'}, {'role': 'user', 'content': 'My booking reference is XYZ901, my flight number is LMN456, and my name is Olivia Harris.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"XYZ901","full_name":"Olivia Harris","flight_number":"LMN456"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_j8PsZkx4V0ujifJLIQvKs5PV'}, {'role': 'assistant', 'tool_call': {'name': 'check_next_available_flight', 'arguments': '{"booking_reference":"XYZ901"}'}}, {'role': 'tool', 'content': 'Next available flight: LMG091 at 10:00 AM Tomorrow', 'tool_call_id': 'call_eiSje47EQc1B656EV8CxqoO4'}, {'role': 'assistant', 'tool_call': {'name': 'rebook_without_fee', 'arguments': '{"booking_reference":"XYZ901"}'}}]

# %%
display_row(8)
# Out:
# Eval DataFrame Row:
# ID                                                                                 8
# context                       I want to cancel my flight due to a medical emergency.
# request                   I want to cancel my flight because of a medical emergency.
# full_name                                                                Laura Adams
# booking_ref                                                                   YZA567
# flight_no                                                                     PQR678
# expected_function                                      process_flexible_cancellation
# expected_inputs        {"booking_reference":"YZA567","medical_certificate":"MC1234"}
# ticket_type                                                                 flexible
# fare_rules                                                                       NaN
# medical_certificate                                                           MC1234
# refund_amount                                                                    NaN
# Name: 8, dtype: object
#
# DataFrame Columns:
# actual_function: process_flexible_cancellation
# actual_inputs: {'booking_reference': 'YZA567', 'medical_certificate': 'Provided'}
# is_correct: False
# transcript:
# {'role': 'user', 'content': 'I want to cancel my flight because of a medical emergency.'}
# {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number to confirm your identity?'}
# {'role': 'user', 'content': 'Sure, my booking reference is YZA567, my full name is Laura Adams, and my flight number is PQR678.'}
# {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"YZA567","full_name":"Laura Adams","flight_number":"PQR678"}'}}
# {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_b0SaYU7uRmzHYuGKuGHiuCF5'}
# {'role': 'assistant', 'tool_call': {'name': 'process_flexible_cancellation', 'arguments': '{"booking_reference":"YZA567","medical_certificate":"Provided"}'}}

# %% [markdown]
# ## Step 3: Improve 4o routine
#
# Let's now leverage o1 again to add in a metaprompting loop to see if we can improve the quality of our evals.
#
# We'll take the following multi-step approach:
# - We'll pass in the current routine + eval results to o1 and ask it analyze the results and update the routine accordingly
# - Since o1 does not currently support structured outputs, we'll chain with output with a 4o to enforce a schema we can parse
# - Finally, we take the new routine and run it back through our eval to generate new results
#
# We'll run this loop a fixed number of times and see what improvements we can make

# %%
def get_openai_response(messages, model, response_format=None):
    try:
        if response_format:
            response = client.chat.completions.create(
                model=model,
                messages=messages,
                response_format={"type": "json_schema", "json_schema": response_format}
            )
        else:
            response = client.chat.completions.create(
                model=model,
                messages=messages
            )
        return response.choices[0].message.content
    except Exception as e:
        print(f"An error occurred: {e}")


OUTPUT_SCHEMA = {
                    "name": "policy_output",
                    "schema": {
                    "type": "object",
                    "properties": {
                        "final_answer": { "type": "string" }
                    },
                    "required": ["final_answer"],
                    "additionalProperties": False
                    },
                    "strict": True
                }

# %%
start_o1_message = [
    {
        "role": "user",
        "content": f"""# Instructions
You are an agent that is responsible for improving the quality of instructions that are provided to a customer service LLM agent. 
Your task is to improve the instructions that are provided to the LLM agent in order to increase accuracy on a test set while adhering to the initial policy. 

## Criteria
- Analyze the existing instructions and the results of the eval. Understand which behaviors lead to failures.
- For example, if the LLM agent is not asking for the booking reference when it is needed, you should add a step to ask for the booking reference.
- Improve the instructions to address the gaps in the eval results.
- Ensure changes made are compliant with the original policy.
- Only use the tools provided.
- Use the functions provided to the best of your ability to ensure the LLM agent can handle the customer service requests effectively. Including gathering data where necessary.
- Try changing the format if this formatting doesn't work well - consider basic XML (e.g. <step> <substep> <if> <case>) or markdown as alternatives.

You will be provided with 4 items:
1) The ground-truth policy for the customer service agent containing detailed instructions on how to handle flight cancellations and changes.
2) Full list of available functions.
3) A routine instruction set.
4) A results that shows the LLMs performance on a test set using this routine instruction set. This dataset contains columns showing:
    - request: This is the initial user request. 
    - expected_function: This is the function we expect the LLM to call at the end of the conversation. 
    - expected_input: This is the input we expect the LLM to provide to the function at the end of the conversation.
    - actual_function: This is the final function the LLM called using the current instructions.
    - actual_input: These are the function parameters the LLM provided based on the current instructions.
    - transcript: This is the conversation transcript between the user and the LLM agent. 
    - is_correct: True/False value depending on if the model responded correctly

You may be provided with a history of edits and evaluations. You can use this information to understand what has been tried before and what has worked or not worked.

# Data

## 1. Original policy
{flight_cancellation_policy}

## 2. Functions
{TOOLS}

# Conclusion

Return the improved policy exactly as written within the defined JSON. Remove all parts from the LLM's answer that are not part of the policy, and do not create additional keys.
"""
     }
]

# %%
import tiktoken 

encoding = tiktoken.get_encoding("o200k_base")

def num_tokens_from_messages(messages):
    entire_input = ""
    for message in messages:
        entire_input += message["content"] + " "
    tokens = encoding.encode(entire_input)
    return len(tokens)

# %% [markdown]
# When improving the routine, consider these approaches:
# - Adding synthetic examples to show the model how to choose between two commonly mistaken functions
# - Given it general guidance on what attributes to look out for which it commonly mislabels
# - Being more specific with your guidance on how to follow the routine.

# %% [markdown]
# <p style="background-color:#f7fff8; padding:15px; border-width:3px; border-color:#e0f0e0; border-style:solid; border-radius:6px"> 🚨
# &nbsp; <b>High Token Warning!:</b> Running the following cell consumes many tokens. Running multiple times may result in a message regarding exceeding a monthy quota.</p>

# %%
# start with data from first run
routines = [flight_cancellation_routine]
results = [df]
accuracies = [round(accuracy * 100, 2)]
o1_messages = start_o1_message.copy()

MAX_TOKENS = 120000

for i in range(3):
    display(Markdown(f"## Iteration {i+1}"))
    
    # Build a candidate message with the most recent eval (full table)
    prev_results = results[-1]
    pf = prev_results.drop(columns=['transcript'])

    new_eval_content = (
        f"## 3. Routine instructions:\n"
        f"{routines[-1]}\n"
        f"## 4. Results table:\n"
        f"{pf.to_json(orient='records')}\n"
    )
    
    # Check token count before adding the newest eval
    candidate_messages = o1_messages + [{"role": "user", "content": new_eval_content}]
    if num_tokens_from_messages(candidate_messages) <= MAX_TOKENS:
        o1_messages.append({"role":"user", "content": new_eval_content})
    else:
        # If we can't even fit the newest eval, consider truncation or error handling
        # For simplicity, we skip truncation logic here
        print("excluding eval content {num_tokens_from_messages(candidate_messages)}")
        pass

    print(f"num tokens {num_tokens_from_messages(o1_messages)}")
    print(f"len messages {len(o1_messages)}")


    # Get the updated routine from the metaprompting assistant
    temp_routine_json = get_openai_response(o1_messages
                                            , O1_MODEL
                                            ,response_format=OUTPUT_SCHEMA)
    #temp_routine_str = temp_routine_json.strip("json```").strip("```")
    new_routine = json.loads(temp_routine_json)["final_answer"]
    routines.append(new_routine)

    eval_df = pd.read_csv('evals/policyEvals.csv')

    # Evaluate the function calls with the current policy on the gpt-4o model
    eval_df, accuracy = evaluate_function_calls(
        eval_df,
        new_routine,
        GPT_MODEL,
        i
    )
    accuracies.append(round(accuracy * 100, 2))
    results.append(eval_df)
    display(Markdown(f"### Accuracy: {accuracy:.2%}"))

    #list the IDs of the failed rows
    failed_ids = eval_df[eval_df['is_correct'] == False].index.tolist()
    display(eval_df.loc[failed_ids])
    eval_df.to_csv(f'evals/results_run_{i+1}.csv', index=False)

    # Instantiate fresh o1 message
    o1_messages = start_o1_message.copy()

    # Attempt to include older examples (omitting 'transcript') within token limit
    older_results = results[:-1][::-1]  # all except the newest, reversed for most recent first
    for old_eval_df in older_results:
        if 'transcript' in old_eval_df.columns:
            truncated_df = old_eval_df.drop(columns=['transcript','cleaned_transcript'])
        else:
            truncated_df = old_eval_df

        old_content = "## Older eval (no transcript):\n" + truncated_df.to_json(orient='records')
        candidate_messages = o1_messages + [{"role": "user", "content": old_content}]
        if num_tokens_from_messages(candidate_messages) <= MAX_TOKENS:
            o1_messages.append({"role": "user", "content": old_content})
        else:
            # If we exceed token limits, stop adding older examples
            break
# Out:
# ## Iteration 1
# num tokens 12301
# len messages 2
# ### Accuracy: 76.47%
#                                                          request  \
# 1   I'd like to initiate a change to my flight for a later date.
# 4                         I want to cancel my refundable ticket.
# 7                              I would like to rebook my flight.
# 11            I need to change my flight within the next 7 days.
#
#                                                                                                         context  \
# 1                                                               I want to change my flight to a different date.
# 4                                                    I want to cancel my flight and I believe it is refundable.
# 7                                  I want to rebook my flight, and I have provided my details for verification.
# 11  I want to change my flight because it's within the next week and I hope I can do it without any extra fees.
#
#          expected_function  \
# 1         apply_change_fee
# 4   process_partial_refund
# 7    process_change_no_fee
# 11   process_change_no_fee
#
#                                             expected_inputs  \
# 1                           {'booking_reference': 'DEF456'}
# 4      {'booking_reference': 'MNO345', 'refund_amount': 65}
# 7   {'booking_reference': 'VWX234', 'new_flight': 'LMG091'}
# 11  {'booking_reference': 'GHI123', 'new_flight': 'LMG091'}
#
#             actual_function  \
# 1   apply_lesser_change_fee
# 4       process_full_refund
# 7     process_change_no_fee
# 11         apply_change_fee
#
#                                                    actual_inputs  is_correct  \
# 1                                {'booking_reference': 'DEF456'}       False
# 4                                {'booking_reference': 'MNO345'}       False
# 7   {'booking_reference': 'VWX234', 'new_flight': 'next Friday'}       False
# 11                               {'booking_reference': 'GHI123'}       False
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   transcript  \
# 1   [{'role': 'user', 'content': 'I'd like to initiate a change to my flight for a later date.'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide me with your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is DEF456, my name is Jane Smith, and my flight number is XYZ123.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_fsjARVPuuRiC3rwcFH6k4s19', function=Function(arguments='{"booking_reference":"DEF456","full_name":"Jane Smith","flight_number":"XYZ123"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_fsjARVPuuRiC3rwcFH6k4s19'}, {'role': 'assistant', 'content': 'Thank you, Jane Smith, for confirming your identity. Now, could you please clarify the specific changes you would like to make to your flight?'}, {'role': 'user', 'content': 'I would like to change my flight to a later date, preferably next month if possible.'}, ChatCompletionMessage(content='Since you want to change your flight to a later date, I will check if this change is customer-initiated or airline-initiated. \n\nLet me proceed with that.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_GpE6s1P6ZlFFJKNrk4iQaNGG', function=Function(arguments='{"booking_reference":"DEF456"}', name='check_ticket_type'), type='function')]), {'role': 'tool', 'content': 'Ticket type: nonrefundable
# Fare rules: ', 'tool_call_id': 'call_GpE6s1P6ZlFFJKNrk4iQaNGG'}, ChatCompletionMessage(content='Your ticket is non-refundable. Now, I need to determine if the change is same-day or in advance. Since you mentioned wanting to change to a later date next month, this will be considered an advance change.\n\nLet me check if there are any applicable change fees for this advance change.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_8HqsSj62atxXwK6WXDrz3kNX', function=Function(arguments='{"booking_reference":"DEF456"}', name='apply_lesser_change_fee'), type='function')])]
# 4                                                                                                                                                                                                                                                                                                                                                          [{'role': 'user', 'content': 'I want to cancel my refundable ticket.'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide me with your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is MNO345, my full name is Sarah Brown, and my flight number is STU678.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_jktiGNnHApMSTpbEdViyt8k1', function=Function(arguments='{"booking_reference":"MNO345","full_name":"Sarah Brown","flight_number":"STU678"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_jktiGNnHApMSTpbEdViyt8k1'}, ChatCompletionMessage(content="Thank you, Sarah Brown, for confirming your identity. Now, I will proceed to handle your cancellation request for your refundable ticket.\n\nI'll check the ticket type to ensure everything is in order.", refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_EP2XkwaKDKNwL2WJTqFxV7Nv', function=Function(arguments='{"booking_reference":"MNO345"}', name='check_ticket_type'), type='function')]), {'role': 'tool', 'content': 'Ticket type: refundable
# Fare rules: partial_refund', 'tool_call_id': 'call_EP2XkwaKDKNwL2WJTqFxV7Nv'}, ChatCompletionMessage(content="Your ticket is refundable, but it falls under partial refund fare rules. Since you are canceling within 24 hours of booking, I will process a full refund for you. \n\nLet's proceed with the full refund.", refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_T85K2ZhXI1vhXl94FJqI0AQg', function=Function(arguments='{"booking_reference":"MNO345"}', name='process_full_refund'), type='function')])]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [{'role': 'user', 'content': 'I would like to rebook my flight.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'My booking reference is VWX234, my flight number is XYZ345, and my name is Lucas Brown.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ubCDRbRPlOw8qCOqM5jXpzHa', function=Function(arguments='{"booking_reference":"VWX234","full_name":"Lucas Brown","flight_number":"XYZ345"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_ubCDRbRPlOw8qCOqM5jXpzHa'}, {'role': 'assistant', 'content': 'Could you please clarify if you would like to change your flight to a specific date or if you need assistance with available options?'}, {'role': 'user', 'content': 'I would like to change my flight to next Friday, please.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_dOvcJu6hqcwuamIRybGUzZBs', function=Function(arguments='{"booking_reference":"VWX234"}', name='check_ticket_type'), type='function')]), {'role': 'tool', 'content': 'Ticket type: flexible
# Fare rules: ', 'tool_call_id': 'call_dOvcJu6hqcwuamIRybGUzZBs'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_upBARCa0wLEOzMx2tgL65N90', function=Function(arguments='{"booking_reference":"VWX234","new_flight":"next Friday"}', name='process_change_no_fee'), type='function')])]
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'role': 'user', 'content': 'I need to change my flight within the next 7 days.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'My booking reference is GHI123, my flight number is PQR789, and my name is Lisa Brown.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_YmOAZCo1dzdKQ2iihOFfJ6Pp', function=Function(arguments='{"booking_reference":"GHI123","full_name":"Lisa Brown","flight_number":"PQR789"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_YmOAZCo1dzdKQ2iihOFfJ6Pp'}, {'role': 'assistant', 'content': 'Could you please clarify what specific change you would like to make to your flight?'}, {'role': 'user', 'content': 'I would like to change my flight date to a later date, if possible. I hope to do this without incurring any extra fees since it's within the next week.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ojkQQJ1ioeRN4bE2RZDvTbmY', function=Function(arguments='{"booking_reference":"GHI123"}', name='apply_change_fee'), type='function')])]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               cleaned_transcript
# 1   [{'role': 'user', 'content': 'I'd like to initiate a change to my flight for a later date.'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide me with your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is DEF456, my name is Jane Smith, and my flight number is XYZ123.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"DEF456","full_name":"Jane Smith","flight_number":"XYZ123"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_fsjARVPuuRiC3rwcFH6k4s19'}, {'role': 'assistant', 'content': 'Thank you, Jane Smith, for confirming your identity. Now, could you please clarify the specific changes you would like to make to your flight?'}, {'role': 'user', 'content': 'I would like to change my flight to a later date, preferably next month if possible.'}, {'role': 'assistant', 'tool_call': {'name': 'check_ticket_type', 'arguments': '{"booking_reference":"DEF456"}'}}, {'role': 'tool', 'content': 'Ticket type: nonrefundable
# Fare rules: ', 'tool_call_id': 'call_GpE6s1P6ZlFFJKNrk4iQaNGG'}, {'role': 'assistant', 'tool_call': {'name': 'apply_lesser_change_fee', 'arguments': '{"booking_reference":"DEF456"}'}}]
# 4                                                                                                                                                                                                                                                                                                                    [{'role': 'user', 'content': 'I want to cancel my refundable ticket.'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide me with your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is MNO345, my full name is Sarah Brown, and my flight number is STU678.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"MNO345","full_name":"Sarah Brown","flight_number":"STU678"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_jktiGNnHApMSTpbEdViyt8k1'}, {'role': 'assistant', 'tool_call': {'name': 'check_ticket_type', 'arguments': '{"booking_reference":"MNO345"}'}}, {'role': 'tool', 'content': 'Ticket type: refundable
# Fare rules: partial_refund', 'tool_call_id': 'call_EP2XkwaKDKNwL2WJTqFxV7Nv'}, {'role': 'assistant', 'tool_call': {'name': 'process_full_refund', 'arguments': '{"booking_reference":"MNO345"}'}}]
# 7                                                                         [{'role': 'user', 'content': 'I would like to rebook my flight.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'My booking reference is VWX234, my flight number is XYZ345, and my name is Lucas Brown.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"VWX234","full_name":"Lucas Brown","flight_number":"XYZ345"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_ubCDRbRPlOw8qCOqM5jXpzHa'}, {'role': 'assistant', 'content': 'Could you please clarify if you would like to change your flight to a specific date or if you need assistance with available options?'}, {'role': 'user', 'content': 'I would like to change my flight to next Friday, please.'}, {'role': 'assistant', 'tool_call': {'name': 'check_ticket_type', 'arguments': '{"booking_reference":"VWX234"}'}}, {'role': 'tool', 'content': 'Ticket type: flexible
# Fare rules: ', 'tool_call_id': 'call_dOvcJu6hqcwuamIRybGUzZBs'}, {'role': 'assistant', 'tool_call': {'name': 'process_change_no_fee', 'arguments': '{"booking_reference":"VWX234","new_flight":"next Friday"}'}}]
# 11                                                                                                                                                                                                                                                                                 [{'role': 'user', 'content': 'I need to change my flight within the next 7 days.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'My booking reference is GHI123, my flight number is PQR789, and my name is Lisa Brown.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"GHI123","full_name":"Lisa Brown","flight_number":"PQR789"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_YmOAZCo1dzdKQ2iihOFfJ6Pp'}, {'role': 'assistant', 'content': 'Could you please clarify what specific change you would like to make to your flight?'}, {'role': 'user', 'content': 'I would like to change my flight date to a later date, if possible. I hope to do this without incurring any extra fees since it's within the next week.'}, {'role': 'assistant', 'tool_call': {'name': 'apply_change_fee', 'arguments': '{"booking_reference":"GHI123"}'}}]
# ## Iteration 2
# num tokens 13823
# len messages 3
# ### Accuracy: 70.59%
#                                                        request  \
# 0                    I would like to cancel my flight, please.
# 4                       I want to cancel my refundable ticket.
# 7                            I would like to rebook my flight.
# 8   I want to cancel my flight because of a medical emergency.
# 11          I need to change my flight within the next 7 days.
#
#                                                                                                         context  \
# 0                                        I want to cancel my flight as I am initiating the cancellation myself.
# 4                                                    I want to cancel my flight and I believe it is refundable.
# 7                                  I want to rebook my flight, and I have provided my details for verification.
# 8                                                        I want to cancel my flight due to a medical emergency.
# 11  I want to change my flight because it's within the next week and I hope I can do it without any extra fees.
#
#                 expected_function  \
# 0          process_partial_refund
# 4          process_partial_refund
# 7           process_change_no_fee
# 8   process_flexible_cancellation
# 11          process_change_no_fee
#
#                                                      expected_inputs  \
# 0              {'booking_reference': 'ABC123', 'refund_amount': 198}
# 4               {'booking_reference': 'MNO345', 'refund_amount': 65}
# 7            {'booking_reference': 'VWX234', 'new_flight': 'LMG091'}
# 8   {'booking_reference': 'YZA567', 'medical_certificate': 'MC1234'}
# 11           {'booking_reference': 'GHI123', 'new_flight': 'LMG091'}
#
#                   actual_function  \
# 0          process_partial_refund
# 4          process_partial_refund
# 7           process_change_no_fee
# 8   process_flexible_cancellation
# 11          process_change_no_fee
#
#                                                                        actual_inputs  \
# 0                            {'booking_reference': 'ABC123', 'refund_amount': 198.0}
# 4                             {'booking_reference': 'MNO345', 'refund_amount': 65.0}
# 7                                                    {'booking_reference': 'VWX234'}
# 8   {'booking_reference': 'YZA567', 'medical_certificate': 'medical_certificate_id'}
# 11                   {'booking_reference': 'GHI123', 'new_flight': 'next Wednesday'}
#
#     is_correct  \
# 0        False
# 4        False
# 7        False
# 8        False
# 11       False
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 transcript  \
# 0   [{'role': 'user', 'content': 'I would like to cancel my flight, please.'}, {'role': 'assistant', 'content': 'Could you please provide your booking reference, full name, and flight number for verification?'}, {'role': 'user', 'content': 'Sure! My booking reference is ABC123, and my flight number is XYZ789. My full name is John Doe.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_T73dOdZuPFExLUzNFo1vTpl4', function=Function(arguments='{"booking_reference":"ABC123","full_name":"John Doe","flight_number":"XYZ789"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_T73dOdZuPFExLUzNFo1vTpl4'}, {'role': 'assistant', 'content': 'Thank you for verifying your identity, John Doe. Now, could you please clarify if this cancellation is customer-initiated or airline-initiated?'}, {'role': 'user', 'content': 'I am initiating the cancellation myself.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_Cbq5KXCWcakarPp8ABNeDelD', function=Function(arguments='{"booking_reference":"ABC123"}', name='check_ticket_type'), type='function')]), {'role': 'tool', 'content': 'Ticket type: refundable
# Fare rules: partial_refund', 'tool_call_id': 'call_Cbq5KXCWcakarPp8ABNeDelD'}, {'role': 'assistant', 'content': 'Since your ticket is refundable, could you please let me know if the booking was made within the last 24 hours?'}, {'role': 'user', 'content': 'The booking was made more than 24 hours ago.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_Waho78GGo25IRMflFicrpTPY', function=Function(arguments='{"booking_reference":"ABC123"}', name='check_fare_rules'), type='function')]), {'role': 'tool', 'content': 'Ticket type: refundable
# Fare rules: partial_refund
# Refund amount: 198.0', 'tool_call_id': 'call_Waho78GGo25IRMflFicrpTPY'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ohj22obHAbyOJVGRKo4rmmgL', function=Function(arguments='{"booking_reference":"ABC123","refund_amount":198.0}', name='process_partial_refund'), type='function')])]
# 4                                                                                                                                                                                                                                      [{'role': 'user', 'content': 'I want to cancel my refundable ticket.'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is MNO345, my name is Sarah Brown, and my flight number is STU678.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_XeXwOg6yPUOsaJMmGVs27iT3', function=Function(arguments='{"booking_reference":"MNO345","full_name":"Sarah Brown","flight_number":"STU678"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_XeXwOg6yPUOsaJMmGVs27iT3'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_BvU6ZXOP0y7x1ueVrPZliitv', function=Function(arguments='{"booking_reference":"MNO345"}', name='check_ticket_type'), type='function')]), {'role': 'tool', 'content': 'Ticket type: refundable
# Fare rules: partial_refund', 'tool_call_id': 'call_BvU6ZXOP0y7x1ueVrPZliitv'}, {'role': 'assistant', 'content': 'Since your ticket is refundable, I need to know if your booking was made within the last 24 hours. Was it?'}, {'role': 'user', 'content': 'No, my booking was made more than 24 hours ago.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_hz5UnM6lI8mo8dtUUc1bHpCN', function=Function(arguments='{"booking_reference":"MNO345"}', name='check_fare_rules'), type='function')]), {'role': 'tool', 'content': 'Ticket type: refundable
# Fare rules: partial_refund
# Refund amount: 65.0', 'tool_call_id': 'call_hz5UnM6lI8mo8dtUUc1bHpCN'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_VyYvJSVfqqARBkvvbE5TFe8T', function=Function(arguments='{"booking_reference":"MNO345","refund_amount":65.0}', name='process_partial_refund'), type='function')])]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [{'role': 'user', 'content': 'I would like to rebook my flight.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'My booking reference is VWX234, my flight number is XYZ345, and my name is Lucas Brown.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_TrHiWdELNYBosbOp0RFsjbUE', function=Function(arguments='{"booking_reference":"VWX234","full_name":"Lucas Brown","flight_number":"XYZ345"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_TrHiWdELNYBosbOp0RFsjbUE'}, {'role': 'assistant', 'content': 'Could you please clarify the details of the change you would like to make for your flight?'}, {'role': 'user', 'content': 'I would like to rebook my flight to a different date. I’m flexible with dates, so I can provide options based on availability.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_CFxBOBMAPxdLjsNbCuSi2JA8', function=Function(arguments='{"booking_reference":"VWX234"}', name='check_ticket_type'), type='function')]), {'role': 'tool', 'content': 'Ticket type: flexible
# Fare rules: ', 'tool_call_id': 'call_CFxBOBMAPxdLjsNbCuSi2JA8'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_9QARAvTo3zXzVyRNeMeKBeUU', function=Function(arguments='{"booking_reference":"VWX234"}', name='process_change_no_fee'), type='function')])]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [{'role': 'user', 'content': 'I want to cancel my flight because of a medical emergency.'}, {'role': 'assistant', 'content': 'Could you please provide your booking reference, full name, and flight number for verification?'}, {'role': 'user', 'content': 'My booking reference is YZA567, my flight number is PQR678, and my name is Laura Adams.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_JCvkz9Qrt4DH2egJMfP3yo0y', function=Function(arguments='{"booking_reference":"YZA567","full_name":"Laura Adams","flight_number":"PQR678"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_JCvkz9Qrt4DH2egJMfP3yo0y'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ZpsUDoIsRijrlvyODsoG5l11', function=Function(arguments='{"booking_reference":"YZA567","medical_certificate":"medical_certificate_id"}', name='process_flexible_cancellation'), type='function')])]
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [{'role': 'user', 'content': 'I need to change my flight within the next 7 days.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'My booking reference is GHI123, my flight number is PQR789, and my name is Lisa Brown.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_Zv4SPtdpU1lo1PrnPn0LBWa4', function=Function(arguments='{"booking_reference":"GHI123","full_name":"Lisa Brown","flight_number":"PQR789"}', name='verify_identity'), type='function')]), {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_Zv4SPtdpU1lo1PrnPn0LBWa4'}, {'role': 'assistant', 'content': 'Could you please provide the new desired date for your flight change?'}, {'role': 'user', 'content': 'I would like to change my flight to next Wednesday, which is one week from today.'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_ko6xIrNryj65FCJWrwrtMVoE', function=Function(arguments='{"booking_reference":"GHI123"}', name='check_ticket_type'), type='function')]), {'role': 'tool', 'content': 'Ticket type: flexible
# Fare rules: ', 'tool_call_id': 'call_ko6xIrNryj65FCJWrwrtMVoE'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_xSRqxLf4JjN5exdabX42EsV3', function=Function(arguments='{"booking_reference":"GHI123","new_flight":"next Wednesday"}', name='process_change_no_fee'), type='function')])]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     cleaned_transcript
# 0   [{'role': 'user', 'content': 'I would like to cancel my flight, please.'}, {'role': 'assistant', 'content': 'Could you please provide your booking reference, full name, and flight number for verification?'}, {'role': 'user', 'content': 'Sure! My booking reference is ABC123, and my flight number is XYZ789. My full name is John Doe.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"ABC123","full_name":"John Doe","flight_number":"XYZ789"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_T73dOdZuPFExLUzNFo1vTpl4'}, {'role': 'assistant', 'content': 'Thank you for verifying your identity, John Doe. Now, could you please clarify if this cancellation is customer-initiated or airline-initiated?'}, {'role': 'user', 'content': 'I am initiating the cancellation myself.'}, {'role': 'assistant', 'tool_call': {'name': 'check_ticket_type', 'arguments': '{"booking_reference":"ABC123"}'}}, {'role': 'tool', 'content': 'Ticket type: refundable
# Fare rules: partial_refund', 'tool_call_id': 'call_Cbq5KXCWcakarPp8ABNeDelD'}, {'role': 'assistant', 'content': 'Since your ticket is refundable, could you please let me know if the booking was made within the last 24 hours?'}, {'role': 'user', 'content': 'The booking was made more than 24 hours ago.'}, {'role': 'assistant', 'tool_call': {'name': 'check_fare_rules', 'arguments': '{"booking_reference":"ABC123"}'}}, {'role': 'tool', 'content': 'Ticket type: refundable
# Fare rules: partial_refund
# Refund amount: 198.0', 'tool_call_id': 'call_Waho78GGo25IRMflFicrpTPY'}, {'role': 'assistant', 'tool_call': {'name': 'process_partial_refund', 'arguments': '{"booking_reference":"ABC123","refund_amount":198.0}'}}]
# 4                                                                                                                                                                                                                                      [{'role': 'user', 'content': 'I want to cancel my refundable ticket.'}, {'role': 'assistant', 'content': 'I can help you with that. First, I need to confirm your identity. Please provide your booking reference, full name, and flight number.'}, {'role': 'user', 'content': 'My booking reference is MNO345, my name is Sarah Brown, and my flight number is STU678.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"MNO345","full_name":"Sarah Brown","flight_number":"STU678"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_XeXwOg6yPUOsaJMmGVs27iT3'}, {'role': 'assistant', 'tool_call': {'name': 'check_ticket_type', 'arguments': '{"booking_reference":"MNO345"}'}}, {'role': 'tool', 'content': 'Ticket type: refundable
# Fare rules: partial_refund', 'tool_call_id': 'call_BvU6ZXOP0y7x1ueVrPZliitv'}, {'role': 'assistant', 'content': 'Since your ticket is refundable, I need to know if your booking was made within the last 24 hours. Was it?'}, {'role': 'user', 'content': 'No, my booking was made more than 24 hours ago.'}, {'role': 'assistant', 'tool_call': {'name': 'check_fare_rules', 'arguments': '{"booking_reference":"MNO345"}'}}, {'role': 'tool', 'content': 'Ticket type: refundable
# Fare rules: partial_refund
# Refund amount: 65.0', 'tool_call_id': 'call_hz5UnM6lI8mo8dtUUc1bHpCN'}, {'role': 'assistant', 'tool_call': {'name': 'process_partial_refund', 'arguments': '{"booking_reference":"MNO345","refund_amount":65.0}'}}]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [{'role': 'user', 'content': 'I would like to rebook my flight.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'My booking reference is VWX234, my flight number is XYZ345, and my name is Lucas Brown.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"VWX234","full_name":"Lucas Brown","flight_number":"XYZ345"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_TrHiWdELNYBosbOp0RFsjbUE'}, {'role': 'assistant', 'content': 'Could you please clarify the details of the change you would like to make for your flight?'}, {'role': 'user', 'content': 'I would like to rebook my flight to a different date. I’m flexible with dates, so I can provide options based on availability.'}, {'role': 'assistant', 'tool_call': {'name': 'check_ticket_type', 'arguments': '{"booking_reference":"VWX234"}'}}, {'role': 'tool', 'content': 'Ticket type: flexible
# Fare rules: ', 'tool_call_id': 'call_CFxBOBMAPxdLjsNbCuSi2JA8'}, {'role': 'assistant', 'tool_call': {'name': 'process_change_no_fee', 'arguments': '{"booking_reference":"VWX234"}'}}]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [{'role': 'user', 'content': 'I want to cancel my flight because of a medical emergency.'}, {'role': 'assistant', 'content': 'Could you please provide your booking reference, full name, and flight number for verification?'}, {'role': 'user', 'content': 'My booking reference is YZA567, my flight number is PQR678, and my name is Laura Adams.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"YZA567","full_name":"Laura Adams","flight_number":"PQR678"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_JCvkz9Qrt4DH2egJMfP3yo0y'}, {'role': 'assistant', 'tool_call': {'name': 'process_flexible_cancellation', 'arguments': '{"booking_reference":"YZA567","medical_certificate":"medical_certificate_id"}'}}]
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [{'role': 'user', 'content': 'I need to change my flight within the next 7 days.'}, {'role': 'assistant', 'content': 'Could you please provide me with your booking reference, full name, and flight number so I can assist you further?'}, {'role': 'user', 'content': 'My booking reference is GHI123, my flight number is PQR789, and my name is Lisa Brown.'}, {'role': 'assistant', 'tool_call': {'name': 'verify_identity', 'arguments': '{"booking_reference":"GHI123","full_name":"Lisa Brown","flight_number":"PQR789"}'}}, {'role': 'tool', 'content': 'True', 'tool_call_id': 'call_Zv4SPtdpU1lo1PrnPn0LBWa4'}, {'role': 'assistant', 'content': 'Could you please provide the new desired date for your flight change?'}, {'role': 'user', 'content': 'I would like to change my flight to next Wednesday, which is one week from today.'}, {'role': 'assistant', 'tool_call': {'name': 'check_ticket_type', 'arguments': '{"booking_reference":"GHI123"}'}}, {'role': 'tool', 'content': 'Ticket type: flexible
# Fare rules: ', 'tool_call_id': 'call_ko6xIrNryj65FCJWrwrtMVoE'}, {'role': 'assistant', 'tool_call': {'name': 'process_change_no_fee', 'arguments': '{"booking_reference":"GHI123","new_flight":"next Wednesday"}'}}]
# ## Iteration 3
# num tokens 15270
# len messages 4

# %%
# Plot accuracy over runs
plt.plot(range(1,len(accuracies)+1), accuracies, marker='o')
plt.title('Accuracy over time')
plt.xlabel('Run number')
plt.ylabel('Accuracy')
plt.savefig('metaprompt_accuracy.png')
plt.show()

# %%
# Print best routine
best_routine = routines[accuracies.index(max(accuracies))]
display(Markdown(f"## Best Routine\n{best_routine}"))

# %%
routines[accuracies.index(max(accuracies))]
